# %%
# import zipfile
# import os

# def unzip_file(zip_path, extract_to='.'):
#     if not zipfile.is_zipfile(zip_path):
#         print(f"❌ The file '{zip_path}' is not a valid zip file.")
#         return

#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)
#         print(f"✅ Extracted '{zip_path}' to '{extract_to}'")

# # Example usage
# zip_path = 'merge_data 2.zip'        # Replace with your zip file
# extract_to = './output'       # Replace with your desired output directory

# os.makedirs(extract_to, exist_ok=True)
# unzip_file(zip_path, extract_to)

# %%
# !pip install torch torchvision scikit_learn timm numpy

# %%
import os
import time
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from sklearn.utils.class_weight import compute_class_weight
import timm
import numpy as np
from tqdm import tqdm
from datetime import datetime
from collections import Counter
from timm.data import Mixup
import logging

# ───────────── SETUP ─────────────
torch.backends.cudnn.benchmark = True

# Logging
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = f"emotion_training_log_{timestamp}.log"
logging.basicConfig(
    filename=log_file,
    filemode="w",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console.setFormatter(formatter)
logging.getLogger().addHandler(console)

# ───────────── CONFIG ─────────────
DATA_DIR = "output/merge_data"
IMG_SIZE = 224
BATCH_SIZE = 128
EPOCHS = 30
NUM_CLASSES = 4
MODEL_NAME = "convnext_tiny"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PATIENCE = 5

logging.info(f"Training on: {DEVICE}")
logging.info(f"Using model: {MODEL_NAME}")

# ───────────── TRANSFORMS ─────────────
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.expand(3, -1, -1) if x.shape[0] == 1 else x),
    transforms.Normalize([0.5]*3, [0.5]*3)
])

# ───────────── DATASET ─────────────
logging.info("\U0001F4C2 Loading dataset...")
dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
logging.info(f"✅ Loaded {len(dataset)} images from {DATA_DIR}")
class_names = dataset.classes
logging.info(f"Detected emotion classes: {class_names}")

all_labels = [label for _, label in dataset.samples]
class_counts = dict(Counter(all_labels))
logging.info(f"Class distribution (folder index): {class_counts}")

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_ds, val_ds = torch.utils.data.random_split(dataset, [train_size, val_size])
logging.info(f"Split: {train_size} training, {val_size} validation")

num_workers = os.cpu_count() // 2
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=num_workers, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True, persistent_workers=True)

# ───────────── CLASS WEIGHTS ─────────────
weights = compute_class_weight('balanced', classes=np.unique(all_labels), y=all_labels)
weights = torch.tensor(weights, dtype=torch.float)
weights[2] *= 0.5  # Neutral
weights[0] *= 1.2  # Angry
weights[3] *= 1.1  # Sad
weights = weights.to(DEVICE)
logging.info(f"⚖️ Modified class weights: {[float(w) for w in weights.cpu()]}\n")

# ───────────── MODEL ─────────────
with torch.amp.autocast(device_type=DEVICE.type, enabled=False):
    base_model = timm.create_model(MODEL_NAME, pretrained=True, num_classes=NUM_CLASSES)
    model = base_model.to(DEVICE)


mixup_fn = Mixup(mixup_alpha=0.2, label_smoothing=0.1, num_classes=NUM_CLASSES)
criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

# ───────────── TRAIN FUNCTION ─────────────
def train():
    best_acc = 0.0
    patience_counter = 0
    scaler = torch.amp.GradScaler(device="cuda")

    for epoch in range(EPOCHS):
        epoch_start = time.time()
        model.train()
        total_loss, correct, total = 0, 0, 0

        for batch_idx, (images, labels) in enumerate(tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}")):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            if mixup_fn:
                images, labels = mixup_fn(images, labels)

            with torch.amp.autocast(device_type="cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            if labels.ndim == 2:
                labels = torch.argmax(labels, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            if batch_idx % 100 == 0:
                logging.info(f"🧪 Epoch {epoch+1} - Batch {batch_idx} | Loss: {loss.item():.4f}")

        train_acc = 100 * correct / total
        val_acc, val_loss = evaluate()
        scheduler.step()
        duration = time.time() - epoch_start

        logging.info(f"📊 Epoch {epoch+1:02d} | Train Loss: {total_loss:.2f} | Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.2f} | Val Acc: {val_acc:.2f}% | Time: {duration:.2f}s")

        if val_acc > best_acc:
            best_acc = val_acc
            patience_counter = 0
            torch.save(model.state_dict(), "best_emotion_model.pt")
            logging.info(f"✅ New best model saved with Val Acc: {val_acc:.2f}%")
        else:
            patience_counter += 1
            logging.info(f"⚠️ No improvement for {patience_counter} epochs.")
            if patience_counter >= PATIENCE:
                logging.info(f"🛑 Early stopping triggered. Best Val Acc: {best_acc:.2f}%")
                break

# ───────────── VALIDATION FUNCTION ─────────────
def evaluate():
    logging.info("🔍 Running validation...")
    model.eval()
    correct, total, total_loss = 0, 0, 0.0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            with torch.amp.autocast(device_type="cuda"):
                outputs = model(images)
                loss = criterion(outputs, labels)
            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    val_acc = 100 * correct / total
    logging.info(f"✅ Validation complete | Val Acc: {val_acc:.2f}% | Val Loss: {total_loss:.2f}")
    return val_acc, total_loss

# ───────────── RUN ─────────────
if __name__ == "__main__":
    logging.info("🚀 Starting training with ConvNeXt-Tiny, MixUp, and early stopping...")
    train()
    logging.info("🏁 Training complete.")

# %%
import os
import time
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from sklearn.utils.class_weight import compute_class_weight
import timm
import numpy as np
from tqdm import tqdm
from datetime import datetime
from collections import Counter
from timm.data import Mixup
import logging
import json
import tensorflow as tf
from PIL import Image
import onnx
import coremltools as ct

# ───────────── SETUP ─────────────
torch.backends.cudnn.benchmark = True

# Logging
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = f"emotion_training_log_{timestamp}.log"
logging.basicConfig(
    filename=log_file,
    filemode="w",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console.setFormatter(formatter)
logging.getLogger().addHandler(console)

# ───────────── CONFIG ─────────────
DATA_DIR = "output/merge_data"
IMG_SIZE = 224
BATCH_SIZE = 128
EPOCHS = 30
NUM_CLASSES = 4
MODEL_NAME = "convnext_tiny"
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
PATIENCE = 5

logging.info(f"Training on: {DEVICE}")
logging.info(f"Using model: {MODEL_NAME}")

# ───────────── TRANSFORMS ─────────────
transform_train = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.expand(3, -1, -1) if x.shape[0] == 1 else x),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # ImageNet stats
])

transform_val = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.expand(3, -1, -1) if x.shape[0] == 1 else x),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# ───────────── DATASET ─────────────
logging.info("\U0001F4C2 Loading dataset...")
train_dataset = datasets.ImageFolder(DATA_DIR, transform=transform_train)
val_dataset = datasets.ImageFolder(DATA_DIR, transform=transform_val)

logging.info(f"✅ Loaded {len(train_dataset)} images from {DATA_DIR}")
class_names = train_dataset.classes
logging.info(f"Detected emotion classes: {class_names}")

# Save class names for mobile deployment
class_mapping = {idx: name for idx, name in enumerate(class_names)}
with open('class_mapping.json', 'w') as f:
    json.dump(class_mapping, f, indent=2)

all_labels = [label for _, label in train_dataset.samples]
class_counts = dict(Counter(all_labels))
logging.info(f"Class distribution (folder index): {class_counts}")

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_ds, val_ds = torch.utils.data.random_split(train_dataset, [train_size, val_size])
logging.info(f"Split: {train_size} training, {val_size} validation")

num_workers = min(8, os.cpu_count())
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, 
                         num_workers=num_workers, pin_memory=True, persistent_workers=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, 
                       num_workers=num_workers, pin_memory=True, persistent_workers=True)

# ───────────── CLASS WEIGHTS ─────────────
weights = compute_class_weight('balanced', classes=np.unique(all_labels), y=all_labels)
weights = torch.tensor(weights, dtype=torch.float)
weights[2] *= 0.5  # Neutral
weights[0] *= 1.2  # Angry
weights[3] *= 1.1  # Sad
weights = weights.to(DEVICE)
logging.info(f"⚖️ Modified class weights: {[float(w) for w in weights.cpu()]}\n")

# ───────────── MODEL ─────────────
class EmotionClassifier(nn.Module):
    def __init__(self, model_name, num_classes):
        super(EmotionClassifier, self).__init__()
        self.backbone = timm.create_model(model_name, pretrained=True, num_classes=0)
        self.classifier = nn.Linear(self.backbone.num_features, num_classes)
        
    def forward(self, x):
        features = self.backbone(x)
        return self.classifier(features)

model = EmotionClassifier(MODEL_NAME, NUM_CLASSES).to(DEVICE)

mixup_fn = Mixup(mixup_alpha=0.2, label_smoothing=0.1, num_classes=NUM_CLASSES)
criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

def train():
    best_acc = 0.0
    patience_counter = 0
    scaler = torch.amp.GradScaler(device="cuda") if DEVICE.type == "cuda" else None

    for epoch in range(EPOCHS):
        epoch_start = time.time()
        model.train()
        total_loss, correct, total = 0, 0, 0

        for batch_idx, (images, labels) in enumerate(tqdm(train_loader, desc=f"Epoch {epoch+1}/{EPOCHS}")):
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            if mixup_fn:
                images, labels = mixup_fn(images, labels)

            if DEVICE.type == "cuda":
                with torch.amp.autocast(device_type="cuda"):
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()
            else:
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            if labels.ndim == 2:
                labels = torch.argmax(labels, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

            if batch_idx % 100 == 0:
                logging.info(f"🧪 Epoch {epoch+1} - Batch {batch_idx} | Loss: {loss.item():.4f}")

        train_acc = 100 * correct / total
        val_acc, val_loss = evaluate()
        scheduler.step()
        duration = time.time() - epoch_start

        logging.info(f"📊 Epoch {epoch+1:02d} | Train Loss: {total_loss:.2f} | Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.2f} | Val Acc: {val_acc:.2f}% | Time: {duration:.2f}s")

        if val_acc > best_acc:
            best_acc = val_acc
            patience_counter = 0
            torch.save(model.state_dict(), "best_emotion_model.pt")
            logging.info(f"✅ New best model saved with Val Acc: {val_acc:.2f}%")
        else:
            patience_counter += 1
            logging.info(f"⚠️ No improvement for {patience_counter} epochs.")
            if patience_counter >= PATIENCE:
                logging.info(f"🛑 Early stopping triggered. Best Val Acc: {best_acc:.2f}%")
                break

    return best_acc

def evaluate():
    model.eval()
    correct, total, total_loss = 0, 0, 0.0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            
            if DEVICE.type == "cuda":
                with torch.amp.autocast(device_type="cuda"):
                    outputs = model(images)
                    loss = criterion(outputs, labels)
            else:
                outputs = model(images)
                loss = criterion(outputs, labels)
                
            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    val_acc = 100 * correct / total
    logging.info(f"✅ Validation complete | Val Acc: {val_acc:.2f}% | Val Loss: {total_loss:.2f}")
    return val_acc, total_loss



def convert_to_onnx(model_path="best_emotion_model.pt"):
    """Convert PyTorch model to ONNX"""
    logging.info("🔄 Converting PyTorch to ONNX...")
    
    # Load model
    model.load_state_dict(torch.load(model_path, map_location='cpu'))
    model.eval()
    
    # Create dummy input
    dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
    
    # Export to ONNX
    onnx_path = "emotion_model.onnx"
    torch.onnx.export(
        model,
        dummy_input,
        onnx_path,
        export_params=True,
        opset_version=11,
        do_constant_folding=True,
        input_names=['input'],
        output_names=['output'],
        dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}}
    )
    
    logging.info(f"✅ ONNX model saved: {onnx_path}")
    return onnx_path

def convert_to_tflite(onnx_path="emotion_model.onnx"):
    """Convert ONNX to TensorFlow Lite"""
    logging.info("🔄 Converting ONNX to TensorFlow Lite...")
    
    try:
        # Import onnx2tf for conversion
        import onnx2tf
        
        # Convert ONNX to TensorFlow SavedModel
        onnx2tf.convert(
            input_onnx_file_path=onnx_path,
            output_folder_path="emotion_tf_model",
            copy_onnx_input_output_names_to_tflite=True,
            non_verbose=True
        )
        
        # Convert SavedModel to TFLite
        converter = tf.lite.TFLiteConverter.from_saved_model("emotion_tf_model")
        
        # Apply optimizations
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        
        # Quantization for smaller model size
        def representative_data_gen():
            for _ in range(100):
                # Generate representative data
                data = np.random.random((1, IMG_SIZE, IMG_SIZE, 3)).astype(np.float32)
                # Apply ImageNet normalization
                data = (data - np.array([0.485, 0.456, 0.406])) / np.array([0.229, 0.224, 0.225])
                yield [data]
        
        converter.representative_dataset = representative_data_gen
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.uint8
        
        # Convert
        tflite_model = converter.convert()
        
        # Save TFLite model
        tflite_path = "emotion_model.tflite"
        with open(tflite_path, 'wb') as f:
            f.write(tflite_model)
        
        model_size = len(tflite_model) / (1024 * 1024)
        logging.info(f"✅ TFLite model saved: {tflite_path} ({model_size:.2f} MB)")
        
        return tflite_path
        
    except ImportError:
        logging.error("❌ onnx2tf not installed. Install with: pip install onnx2tf")
        return None
    except Exception as e:
        logging.error(f"❌ TFLite conversion failed: {e}")
        # Try alternative method without quantization
        return convert_tflite_alternative(onnx_path)

def convert_tflite_alternative(onnx_path="emotion_model.onnx"):
    """Alternative TFLite conversion without quantization"""
    logging.info("🔄 Trying alternative TFLite conversion...")
    
    try:
        import onnx2tf
        
        # Convert without quantization
        onnx2tf.convert(
            input_onnx_file_path=onnx_path,
            output_folder_path="emotion_tf_model_simple",
            copy_onnx_input_output_names_to_tflite=True,
            non_verbose=True
        )
        
        # Simple conversion without quantization
        converter = tf.lite.TFLiteConverter.from_saved_model("emotion_tf_model_simple")
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        
        tflite_model = converter.convert()
        
        tflite_path = "emotion_model_simple.tflite"
        with open(tflite_path, 'wb') as f:
            f.write(tflite_model)
        
        model_size = len(tflite_model) / (1024 * 1024)
        logging.info(f"✅ TFLite model (simple) saved: {tflite_path} ({model_size:.2f} MB)")
        
        return tflite_path
        
    except Exception as e:
        logging.error(f"❌ Alternative TFLite conversion failed: {e}")
        return None

def convert_to_mlpackage(model_path="best_emotion_model.pt"):
    """Convert PyTorch model to Core ML (.mlpackage)"""
    logging.info("🔄 Converting PyTorch to Core ML (.mlpackage)...")
    
    try:
        # Load model
        model.load_state_dict(torch.load(model_path, map_location='cpu'))
        model.eval()
        
        # Create dummy input
        dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
        
        # Trace the model
        traced_model = torch.jit.trace(model, dummy_input)
        
        # Convert to Core ML
        mlmodel = ct.convert(
            traced_model,
            inputs=[ct.ImageType(
                name="input",
                shape=(1, 3, IMG_SIZE, IMG_SIZE),
                bias=[-0.485/0.229, -0.456/0.224, -0.406/0.225],  # ImageNet normalization
                scale=1.0/np.array([0.229, 0.224, 0.225])
            )],
            outputs=[ct.TensorType(name="output")],
            minimum_deployment_target=ct.target.iOS15,  # Use .mlpackage format
            compute_units=ct.ComputeUnit.ALL
        )
        
        # Set model metadata
        mlmodel.short_description = "Emotion Classification Model"
        mlmodel.author = "AI Team"
        mlmodel.license = "MIT"
        mlmodel.version = "1.0.0"
        
        # Set class labels
        class_labels = list(class_names)
        mlmodel.output_description["output"] = f"Emotion probabilities for classes: {class_labels}"
        
        # Add class labels to the model
        labels_to_class_mapping = {i: class_names[i] for i in range(len(class_names))}
        
        # Save as .mlpackage
        mlpackage_path = "EmotionClassifier.mlpackage"
        mlmodel.save(mlpackage_path)
        
        logging.info(f"✅ Core ML model saved: {mlpackage_path}")
        
        # Also save metadata
        metadata = {
            "model_type": "emotion_classification",
            "input_size": [IMG_SIZE, IMG_SIZE],
            "classes": class_names,
            "normalization": {
                "mean": [0.485, 0.456, 0.406],
                "std": [0.229, 0.224, 0.225]
            }
        }
        
        with open('model_metadata.json', 'w') as f:
            json.dump(metadata, f, indent=2)
        
        return mlpackage_path
        
    except ImportError:
        logging.error("❌ coremltools not installed. Install with: pip install coremltools")
        return None
    except Exception as e:
        logging.error(f"❌ Core ML conversion failed: {e}")
        return None

if __name__ == "__main__":
    logging.info("🚀 Starting emotion classification training for mobile deployment...")
    
    # Train the model
    logging.info("📚 Starting training...")
    best_accuracy = train()
    logging.info(f"🏁 Training complete. Best accuracy: {best_accuracy:.2f}%")
    
    # Convert models for mobile deployment
    logging.info("📱 Converting models for mobile deployment...")
    
    try:
        # Step 1: Convert to ONNX (intermediate format)
        onnx_path = convert_to_onnx("best_emotion_model.pt")
        
        # Step 2: Convert to TFLite (Android)
        if onnx_path:
            tflite_path = convert_to_tflite(onnx_path)
            if tflite_path:
                logging.info(f"✅ Android TFLite model ready: {tflite_path}")
            else:
                logging.warning("⚠️ TFLite conversion failed")
        
        # Step 3: Convert to Core ML (.mlpackage for iOS)
        mlpackage_path = convert_to_mlpackage("best_emotion_model.pt")
        if mlpackage_path:
            logging.info(f"✅ iOS Core ML model ready: {mlpackage_path}")
        else:
            logging.warning("⚠️ Core ML conversion failed")
        

        logging.info("🎉 Mobile deployment package complete!")
        logging.info("📋 Check DEPLOYMENT_SUMMARY.md for integration details")
        
        # List all generated files
        logging.info("\n📁 Generated files:")
        generated_files = [
            "best_emotion_model.pt",
            "emotion_model.onnx", 
            "emotion_model.tflite",
            "emotion_model_simple.tflite",
            "EmotionClassifier.mlpackage",
            "class_mapping.json",
            "model_metadata.json",
            "DEPLOYMENT_SUMMARY.md"
        ]
        
        for file in generated_files:
            if os.path.exists(file):
                size = os.path.getsize(file) / (1024 * 1024)
                logging.info(f"   ✅ {file} ({size:.2f} MB)")
            else:
                logging.info(f"   ❌ {file} (not created)")
                
    except Exception as e:
        logging.error(f"❌ Error during mobile conversion: {e}")
        logging.info("\n📦 Required packages for mobile conversion:")
        logging.info("pip install onnx onnx2tf tensorflow coremltools")
        
    logging.info(f"\n🏆 Training completed with best accuracy: {best_accuracy:.2f}%")
    logging.info("📱 Mobile models ready for deployment!")
# Out:
# WARNING:coremltools:scikit-learn version 1.7.0 is not supported. Minimum required version: 0.17. Maximum required version: 1.5.1. Disabling scikit-learn conversion API.
# WARNING:coremltools:TensorFlow version 2.13.0 has not been tested with coremltools. You may run into unexpected errors. TensorFlow 2.12.0 is the most recent version that has been tested.
# WARNING:coremltools:Torch version 2.7.1+cu126 has not been tested with coremltools. You may run into unexpected errors. Torch 2.5.0 is the most recent version that has been tested.
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLCPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLGPUComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLNeuralEngineComputeDeviceProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLComputePlanProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelProxy: No module named 'coremltools.libcoremlpython'
# WARNING:coremltools:Failed to load _MLModelAssetProxy: No module named 'coremltools.libcoremlpython'
# INFO:root:Training on: cuda
# 2025-06-14 17:22:59,553 - INFO - Training on: cuda
# INFO:root:Using model: convnext_tiny
# 2025-06-14 17:22:59,555 - INFO - Using model: convnext_tiny
# INFO:root:📂 Loading dataset...
# 2025-06-14 17:22:59,558 - INFO - 📂 Loading dataset...
# INFO:root:✅ Loaded 69305 images from output/merge_data
# 2025-06-14 17:23:00,063 - INFO - ✅ Loaded 69305 images from output/merge_data
# INFO:root:Detected emotion classes: ['angry', 'happy', 'neutral', 'sad']
# 2025-06-14 17:23:00,065 - INFO - Detected emotion classes: ['angry', 'happy', 'neutral', 'sad']
# INFO:root:Class distribution (folder index): {0: 12733, 1: 20829, 2: 21324, 3: 14419}
# 2025-06-14 17:23:00,077 - INFO - Class distribution (folder index): {0: 12733, 1: 20829, 2: 21324, 3: 14419}
# INFO:root:Split: 55444 training, 13861 validation
# 2025-06-14 17:23:00,085 - INFO - Split: 55444 training, 13861 validation
# INFO:root:⚖️ Modified class weights: [1.6328831911087036, 0.831833004951477, 0.40626171231269836, 1.3217889070510864]
#
# 2025-06-14 17:23:00,123 - INFO - ⚖️ Modified class weights: [1.6328831911087036, 0.831833004951477, 0.40626171231269836, 1.3217889070510864]
#
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 17:23:00,493 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# INFO:timm.models._hub:[timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 17:23:00,551 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:root:🚀 Starting emotion classification training for mobile deployment...
# 2025-06-14 17:23:00,625 - INFO - 🚀 Starting emotion classification training for mobile deployment...
# INFO:root:📚 Starting training...
# 2025-06-14 17:23:00,627 - INFO - 📚 Starting training...
# Epoch 1/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 1 - Batch 0 | Loss: 1.5182
# 2025-06-14 17:23:10,394 - INFO - 🧪 Epoch 1 - Batch 0 | Loss: 1.5182
# Epoch 1/30:  23%|██▎       | 100/434 [00:26<00:56,  5.92it/s]INFO:root:🧪 Epoch 1 - Batch 100 | Loss: 1.2719
# 2025-06-14 17:23:27,241 - INFO - 🧪 Epoch 1 - Batch 100 | Loss: 1.2719
# Epoch 1/30:  46%|████▌     | 200/434 [00:43<00:39,  5.90it/s]INFO:root:🧪 Epoch 1 - Batch 200 | Loss: 0.9226
# 2025-06-14 17:23:44,149 - INFO - 🧪 Epoch 1 - Batch 200 | Loss: 0.9226
# Epoch 1/30:  69%|██████▉   | 300/434 [01:00<00:22,  5.89it/s]INFO:root:🧪 Epoch 1 - Batch 300 | Loss: 0.7163
# 2025-06-14 17:24:01,129 - INFO - 🧪 Epoch 1 - Batch 300 | Loss: 0.7163
# Epoch 1/30:  92%|█████████▏| 400/434 [01:17<00:05,  5.91it/s]INFO:root:🧪 Epoch 1 - Batch 400 | Loss: 0.6944
# 2025-06-14 17:24:18,056 - INFO - 🧪 Epoch 1 - Batch 400 | Loss: 0.6944
# Epoch 1/30: 100%|██████████| 434/434 [01:24<00:00,  5.13it/s]
# INFO:root:✅ Validation complete | Val Acc: 80.57% | Val Loss: 46.34
# 2025-06-14 17:24:36,184 - INFO - ✅ Validation complete | Val Acc: 80.57% | Val Loss: 46.34
# INFO:root:📊 Epoch 01 | Train Loss: 439.73 | Train Acc: 53.42% | Val Loss: 46.34 | Val Acc: 80.57% | Time: 95.56s
# 2025-06-14 17:24:36,188 - INFO - 📊 Epoch 01 | Train Loss: 439.73 | Train Acc: 53.42% | Val Loss: 46.34 | Val Acc: 80.57% | Time: 95.56s
# INFO:root:✅ New best model saved with Val Acc: 80.57%
# 2025-06-14 17:24:36,399 - INFO - ✅ New best model saved with Val Acc: 80.57%
# Epoch 2/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 2 - Batch 0 | Loss: 0.5807
# 2025-06-14 17:24:37,222 - INFO - 🧪 Epoch 2 - Batch 0 | Loss: 0.5807
# Epoch 2/30:  23%|██▎       | 100/434 [00:17<00:56,  5.88it/s]INFO:root:🧪 Epoch 2 - Batch 100 | Loss: 1.0769
# 2025-06-14 17:24:54,195 - INFO - 🧪 Epoch 2 - Batch 100 | Loss: 1.0769
# Epoch 2/30:  46%|████▌     | 200/434 [00:34<00:39,  5.88it/s]INFO:root:🧪 Epoch 2 - Batch 200 | Loss: 0.5627
# 2025-06-14 17:25:11,231 - INFO - 🧪 Epoch 2 - Batch 200 | Loss: 0.5627
# Epoch 2/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.86it/s]INFO:root:🧪 Epoch 2 - Batch 300 | Loss: 1.0255
# 2025-06-14 17:25:28,288 - INFO - 🧪 Epoch 2 - Batch 300 | Loss: 1.0255
# Epoch 2/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.87it/s]INFO:root:🧪 Epoch 2 - Batch 400 | Loss: 0.5696
# 2025-06-14 17:25:45,340 - INFO - 🧪 Epoch 2 - Batch 400 | Loss: 0.5696
# Epoch 2/30: 100%|██████████| 434/434 [01:14<00:00,  5.83it/s]
# INFO:root:✅ Validation complete | Val Acc: 84.32% | Val Loss: 42.08
# 2025-06-14 17:25:58,834 - INFO - ✅ Validation complete | Val Acc: 84.32% | Val Loss: 42.08
# INFO:root:📊 Epoch 02 | Train Loss: 305.56 | Train Acc: 80.61% | Val Loss: 42.08 | Val Acc: 84.32% | Time: 82.44s
# 2025-06-14 17:25:58,837 - INFO - 📊 Epoch 02 | Train Loss: 305.56 | Train Acc: 80.61% | Val Loss: 42.08 | Val Acc: 84.32% | Time: 82.44s
# INFO:root:✅ New best model saved with Val Acc: 84.32%
# 2025-06-14 17:25:59,017 - INFO - ✅ New best model saved with Val Acc: 84.32%
# Epoch 3/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 3 - Batch 0 | Loss: 0.5477
# 2025-06-14 17:25:59,924 - INFO - 🧪 Epoch 3 - Batch 0 | Loss: 0.5477
# Epoch 3/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 3 - Batch 100 | Loss: 0.5325
# 2025-06-14 17:26:17,013 - INFO - 🧪 Epoch 3 - Batch 100 | Loss: 0.5325
# Epoch 3/30:  46%|████▌     | 200/434 [00:34<00:39,  5.89it/s]INFO:root:🧪 Epoch 3 - Batch 200 | Loss: 0.5205
# 2025-06-14 17:26:33,997 - INFO - 🧪 Epoch 3 - Batch 200 | Loss: 0.5205
# Epoch 3/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.88it/s]INFO:root:🧪 Epoch 3 - Batch 300 | Loss: 0.5358
# 2025-06-14 17:26:51,007 - INFO - 🧪 Epoch 3 - Batch 300 | Loss: 0.5358
# Epoch 3/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.85it/s]INFO:root:🧪 Epoch 3 - Batch 400 | Loss: 0.6605
# 2025-06-14 17:27:08,056 - INFO - 🧪 Epoch 3 - Batch 400 | Loss: 0.6605
# Epoch 3/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 86.80% | Val Loss: 36.00
# 2025-06-14 17:27:21,603 - INFO - ✅ Validation complete | Val Acc: 86.80% | Val Loss: 36.00
# INFO:root:📊 Epoch 03 | Train Loss: 288.20 | Train Acc: 83.44% | Val Loss: 36.00 | Val Acc: 86.80% | Time: 82.59s
# 2025-06-14 17:27:21,606 - INFO - 📊 Epoch 03 | Train Loss: 288.20 | Train Acc: 83.44% | Val Loss: 36.00 | Val Acc: 86.80% | Time: 82.59s
# INFO:root:✅ New best model saved with Val Acc: 86.80%
# 2025-06-14 17:27:21,794 - INFO - ✅ New best model saved with Val Acc: 86.80%
# Epoch 4/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 4 - Batch 0 | Loss: 0.4341
# 2025-06-14 17:27:22,740 - INFO - 🧪 Epoch 4 - Batch 0 | Loss: 0.4341
# Epoch 4/30:  23%|██▎       | 100/434 [00:17<00:57,  5.84it/s]INFO:root:🧪 Epoch 4 - Batch 100 | Loss: 0.5048
# 2025-06-14 17:27:39,854 - INFO - 🧪 Epoch 4 - Batch 100 | Loss: 0.5048
# Epoch 4/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 4 - Batch 200 | Loss: 0.4701
# 2025-06-14 17:27:56,864 - INFO - 🧪 Epoch 4 - Batch 200 | Loss: 0.4701
# Epoch 4/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.85it/s]INFO:root:🧪 Epoch 4 - Batch 300 | Loss: 0.5956
# 2025-06-14 17:28:13,903 - INFO - 🧪 Epoch 4 - Batch 300 | Loss: 0.5956
# Epoch 4/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.85it/s]INFO:root:🧪 Epoch 4 - Batch 400 | Loss: 1.0283
# 2025-06-14 17:28:30,934 - INFO - 🧪 Epoch 4 - Batch 400 | Loss: 1.0283
# Epoch 4/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 87.92% | Val Loss: 36.15
# 2025-06-14 17:28:44,461 - INFO - ✅ Validation complete | Val Acc: 87.92% | Val Loss: 36.15
# INFO:root:📊 Epoch 04 | Train Loss: 276.44 | Train Acc: 85.48% | Val Loss: 36.15 | Val Acc: 87.92% | Time: 82.67s
# 2025-06-14 17:28:44,463 - INFO - 📊 Epoch 04 | Train Loss: 276.44 | Train Acc: 85.48% | Val Loss: 36.15 | Val Acc: 87.92% | Time: 82.67s
# INFO:root:✅ New best model saved with Val Acc: 87.92%
# 2025-06-14 17:28:44,651 - INFO - ✅ New best model saved with Val Acc: 87.92%
# Epoch 5/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 5 - Batch 0 | Loss: 0.5095
# 2025-06-14 17:28:45,527 - INFO - 🧪 Epoch 5 - Batch 0 | Loss: 0.5095
# Epoch 5/30:  23%|██▎       | 100/434 [00:17<00:56,  5.89it/s]INFO:root:🧪 Epoch 5 - Batch 100 | Loss: 0.4542
# 2025-06-14 17:29:02,556 - INFO - 🧪 Epoch 5 - Batch 100 | Loss: 0.4542
# Epoch 5/30:  46%|████▌     | 200/434 [00:34<00:39,  5.89it/s]INFO:root:🧪 Epoch 5 - Batch 200 | Loss: 1.0158
# 2025-06-14 17:29:19,622 - INFO - 🧪 Epoch 5 - Batch 200 | Loss: 1.0158
# Epoch 5/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.85it/s]INFO:root:🧪 Epoch 5 - Batch 300 | Loss: 0.9913
# 2025-06-14 17:29:36,673 - INFO - 🧪 Epoch 5 - Batch 300 | Loss: 0.9913
# Epoch 5/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.90it/s]INFO:root:🧪 Epoch 5 - Batch 400 | Loss: 1.0371
# 2025-06-14 17:29:53,695 - INFO - 🧪 Epoch 5 - Batch 400 | Loss: 1.0371
# Epoch 5/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 86.03% | Val Loss: 36.51
# 2025-06-14 17:30:07,202 - INFO - ✅ Validation complete | Val Acc: 86.03% | Val Loss: 36.51
# INFO:root:📊 Epoch 05 | Train Loss: 261.79 | Train Acc: 87.54% | Val Loss: 36.51 | Val Acc: 86.03% | Time: 82.55s
# 2025-06-14 17:30:07,205 - INFO - 📊 Epoch 05 | Train Loss: 261.79 | Train Acc: 87.54% | Val Loss: 36.51 | Val Acc: 86.03% | Time: 82.55s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:30:07,207 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 6/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 6 - Batch 0 | Loss: 0.5094
# 2025-06-14 17:30:08,256 - INFO - 🧪 Epoch 6 - Batch 0 | Loss: 0.5094
# Epoch 6/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 6 - Batch 100 | Loss: 0.7711
# 2025-06-14 17:30:25,294 - INFO - 🧪 Epoch 6 - Batch 100 | Loss: 0.7711
# Epoch 6/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 6 - Batch 200 | Loss: 0.4495
# 2025-06-14 17:30:42,352 - INFO - 🧪 Epoch 6 - Batch 200 | Loss: 0.4495
# Epoch 6/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.86it/s]INFO:root:🧪 Epoch 6 - Batch 300 | Loss: 0.4482
# 2025-06-14 17:30:59,395 - INFO - 🧪 Epoch 6 - Batch 300 | Loss: 0.4482
# Epoch 6/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.81it/s]INFO:root:🧪 Epoch 6 - Batch 400 | Loss: 0.5874
# 2025-06-14 17:31:16,469 - INFO - 🧪 Epoch 6 - Batch 400 | Loss: 0.5874
# Epoch 6/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 88.48% | Val Loss: 34.99
# 2025-06-14 17:31:29,961 - INFO - ✅ Validation complete | Val Acc: 88.48% | Val Loss: 34.99
# INFO:root:📊 Epoch 06 | Train Loss: 258.22 | Train Acc: 88.37% | Val Loss: 34.99 | Val Acc: 88.48% | Time: 82.76s
# 2025-06-14 17:31:29,964 - INFO - 📊 Epoch 06 | Train Loss: 258.22 | Train Acc: 88.37% | Val Loss: 34.99 | Val Acc: 88.48% | Time: 82.76s
# INFO:root:✅ New best model saved with Val Acc: 88.48%
# 2025-06-14 17:31:30,155 - INFO - ✅ New best model saved with Val Acc: 88.48%
# Epoch 7/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 7 - Batch 0 | Loss: 0.8075
# 2025-06-14 17:31:30,947 - INFO - 🧪 Epoch 7 - Batch 0 | Loss: 0.8075
# Epoch 7/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 7 - Batch 100 | Loss: 0.5881
# 2025-06-14 17:31:47,978 - INFO - 🧪 Epoch 7 - Batch 100 | Loss: 0.5881
# Epoch 7/30:  46%|████▌     | 200/434 [00:34<00:39,  5.90it/s]INFO:root:🧪 Epoch 7 - Batch 200 | Loss: 0.4260
# 2025-06-14 17:32:04,982 - INFO - 🧪 Epoch 7 - Batch 200 | Loss: 0.4260
# Epoch 7/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.87it/s]INFO:root:🧪 Epoch 7 - Batch 300 | Loss: 0.7000
# 2025-06-14 17:32:22,006 - INFO - 🧪 Epoch 7 - Batch 300 | Loss: 0.7000
# Epoch 7/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.87it/s]INFO:root:🧪 Epoch 7 - Batch 400 | Loss: 0.4373
# 2025-06-14 17:32:39,073 - INFO - 🧪 Epoch 7 - Batch 400 | Loss: 0.4373
# Epoch 7/30: 100%|██████████| 434/434 [01:14<00:00,  5.83it/s]
# INFO:root:✅ Validation complete | Val Acc: 89.20% | Val Loss: 35.50
# 2025-06-14 17:32:52,681 - INFO - ✅ Validation complete | Val Acc: 89.20% | Val Loss: 35.50
# INFO:root:📊 Epoch 07 | Train Loss: 251.41 | Train Acc: 89.70% | Val Loss: 35.50 | Val Acc: 89.20% | Time: 82.52s
# 2025-06-14 17:32:52,684 - INFO - 📊 Epoch 07 | Train Loss: 251.41 | Train Acc: 89.70% | Val Loss: 35.50 | Val Acc: 89.20% | Time: 82.52s
# INFO:root:✅ New best model saved with Val Acc: 89.20%
# 2025-06-14 17:32:52,868 - INFO - ✅ New best model saved with Val Acc: 89.20%
# Epoch 8/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 8 - Batch 0 | Loss: 0.8125
# 2025-06-14 17:32:53,701 - INFO - 🧪 Epoch 8 - Batch 0 | Loss: 0.8125
# Epoch 8/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 8 - Batch 100 | Loss: 0.4153
# 2025-06-14 17:33:10,800 - INFO - 🧪 Epoch 8 - Batch 100 | Loss: 0.4153
# Epoch 8/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 8 - Batch 200 | Loss: 0.8930
# 2025-06-14 17:33:27,878 - INFO - 🧪 Epoch 8 - Batch 200 | Loss: 0.8930
# Epoch 8/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.86it/s]INFO:root:🧪 Epoch 8 - Batch 300 | Loss: 0.7450
# 2025-06-14 17:33:44,970 - INFO - 🧪 Epoch 8 - Batch 300 | Loss: 0.7450
# Epoch 8/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.85it/s]INFO:root:🧪 Epoch 8 - Batch 400 | Loss: 0.7756
# 2025-06-14 17:34:02,047 - INFO - 🧪 Epoch 8 - Batch 400 | Loss: 0.7756
# Epoch 8/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 88.82% | Val Loss: 37.04
# 2025-06-14 17:34:15,803 - INFO - ✅ Validation complete | Val Acc: 88.82% | Val Loss: 37.04
# INFO:root:📊 Epoch 08 | Train Loss: 250.62 | Train Acc: 89.70% | Val Loss: 37.04 | Val Acc: 88.82% | Time: 82.94s
# 2025-06-14 17:34:15,807 - INFO - 📊 Epoch 08 | Train Loss: 250.62 | Train Acc: 89.70% | Val Loss: 37.04 | Val Acc: 88.82% | Time: 82.94s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:34:15,809 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 9/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 9 - Batch 0 | Loss: 0.3847
# 2025-06-14 17:34:16,706 - INFO - 🧪 Epoch 9 - Batch 0 | Loss: 0.3847
# Epoch 9/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 9 - Batch 100 | Loss: 1.0703
# 2025-06-14 17:34:33,796 - INFO - 🧪 Epoch 9 - Batch 100 | Loss: 1.0703
# Epoch 9/30:  46%|████▌     | 200/434 [00:34<00:39,  5.85it/s]INFO:root:🧪 Epoch 9 - Batch 200 | Loss: 0.5451
# 2025-06-14 17:34:50,872 - INFO - 🧪 Epoch 9 - Batch 200 | Loss: 0.5451
# Epoch 9/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.85it/s]INFO:root:🧪 Epoch 9 - Batch 300 | Loss: 0.3812
# 2025-06-14 17:35:07,953 - INFO - 🧪 Epoch 9 - Batch 300 | Loss: 0.3812
# Epoch 9/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 9 - Batch 400 | Loss: 0.3867
# 2025-06-14 17:35:24,996 - INFO - 🧪 Epoch 9 - Batch 400 | Loss: 0.3867
# Epoch 9/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.07% | Val Loss: 39.30
# 2025-06-14 17:35:38,695 - INFO - ✅ Validation complete | Val Acc: 90.07% | Val Loss: 39.30
# INFO:root:📊 Epoch 09 | Train Loss: 245.03 | Train Acc: 90.92% | Val Loss: 39.30 | Val Acc: 90.07% | Time: 82.89s
# 2025-06-14 17:35:38,697 - INFO - 📊 Epoch 09 | Train Loss: 245.03 | Train Acc: 90.92% | Val Loss: 39.30 | Val Acc: 90.07% | Time: 82.89s
# INFO:root:✅ New best model saved with Val Acc: 90.07%
# 2025-06-14 17:35:38,893 - INFO - ✅ New best model saved with Val Acc: 90.07%
# Epoch 10/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 10 - Batch 0 | Loss: 0.4006
# 2025-06-14 17:35:39,765 - INFO - 🧪 Epoch 10 - Batch 0 | Loss: 0.4006
# Epoch 10/30:  23%|██▎       | 100/434 [00:17<00:56,  5.90it/s]INFO:root:🧪 Epoch 10 - Batch 100 | Loss: 0.3917
# 2025-06-14 17:35:56,825 - INFO - 🧪 Epoch 10 - Batch 100 | Loss: 0.3917
# Epoch 10/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 10 - Batch 200 | Loss: 0.6227
# 2025-06-14 17:36:13,874 - INFO - 🧪 Epoch 10 - Batch 200 | Loss: 0.6227
# Epoch 10/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.89it/s]INFO:root:🧪 Epoch 10 - Batch 300 | Loss: 0.3882
# 2025-06-14 17:36:30,877 - INFO - 🧪 Epoch 10 - Batch 300 | Loss: 0.3882
# Epoch 10/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.86it/s]INFO:root:🧪 Epoch 10 - Batch 400 | Loss: 0.4035
# 2025-06-14 17:36:47,904 - INFO - 🧪 Epoch 10 - Batch 400 | Loss: 0.4035
# Epoch 10/30: 100%|██████████| 434/434 [01:14<00:00,  5.83it/s]
# INFO:root:✅ Validation complete | Val Acc: 89.32% | Val Loss: 37.11
# 2025-06-14 17:37:01,835 - INFO - ✅ Validation complete | Val Acc: 89.32% | Val Loss: 37.11
# INFO:root:📊 Epoch 10 | Train Loss: 237.68 | Train Acc: 92.27% | Val Loss: 37.11 | Val Acc: 89.32% | Time: 82.94s
# 2025-06-14 17:37:01,838 - INFO - 📊 Epoch 10 | Train Loss: 237.68 | Train Acc: 92.27% | Val Loss: 37.11 | Val Acc: 89.32% | Time: 82.94s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:37:01,840 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 11/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 11 - Batch 0 | Loss: 0.3681
# 2025-06-14 17:37:02,660 - INFO - 🧪 Epoch 11 - Batch 0 | Loss: 0.3681
# Epoch 11/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 11 - Batch 100 | Loss: 0.4312
# 2025-06-14 17:37:19,793 - INFO - 🧪 Epoch 11 - Batch 100 | Loss: 0.4312
# Epoch 11/30:  46%|████▌     | 200/434 [00:34<00:40,  5.85it/s]INFO:root:🧪 Epoch 11 - Batch 200 | Loss: 0.4428
# 2025-06-14 17:37:36,858 - INFO - 🧪 Epoch 11 - Batch 200 | Loss: 0.4428
# Epoch 11/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.86it/s]INFO:root:🧪 Epoch 11 - Batch 300 | Loss: 0.3912
# 2025-06-14 17:37:53,934 - INFO - 🧪 Epoch 11 - Batch 300 | Loss: 0.3912
# Epoch 11/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.85it/s]INFO:root:🧪 Epoch 11 - Batch 400 | Loss: 0.6734
# 2025-06-14 17:38:11,023 - INFO - 🧪 Epoch 11 - Batch 400 | Loss: 0.6734
# Epoch 11/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.02% | Val Loss: 36.18
# 2025-06-14 17:38:24,943 - INFO - ✅ Validation complete | Val Acc: 90.02% | Val Loss: 36.18
# INFO:root:📊 Epoch 11 | Train Loss: 235.86 | Train Acc: 92.99% | Val Loss: 36.18 | Val Acc: 90.02% | Time: 83.10s
# 2025-06-14 17:38:24,946 - INFO - 📊 Epoch 11 | Train Loss: 235.86 | Train Acc: 92.99% | Val Loss: 36.18 | Val Acc: 90.02% | Time: 83.10s
# INFO:root:⚠️ No improvement for 2 epochs.
# 2025-06-14 17:38:24,948 - INFO - ⚠️ No improvement for 2 epochs.
# Epoch 12/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 12 - Batch 0 | Loss: 0.3814
# 2025-06-14 17:38:25,690 - INFO - 🧪 Epoch 12 - Batch 0 | Loss: 0.3814
# Epoch 12/30:  23%|██▎       | 100/434 [00:17<00:57,  5.84it/s]INFO:root:🧪 Epoch 12 - Batch 100 | Loss: 0.8340
# 2025-06-14 17:38:42,924 - INFO - 🧪 Epoch 12 - Batch 100 | Loss: 0.8340
# Epoch 12/30:  46%|████▌     | 200/434 [00:34<00:39,  5.85it/s]INFO:root:🧪 Epoch 12 - Batch 200 | Loss: 0.5082
# 2025-06-14 17:39:00,024 - INFO - 🧪 Epoch 12 - Batch 200 | Loss: 0.5082
# Epoch 12/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.85it/s]INFO:root:🧪 Epoch 12 - Batch 300 | Loss: 0.3814
# 2025-06-14 17:39:17,112 - INFO - 🧪 Epoch 12 - Batch 300 | Loss: 0.3814
# Epoch 12/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 12 - Batch 400 | Loss: 0.3908
# 2025-06-14 17:39:34,209 - INFO - 🧪 Epoch 12 - Batch 400 | Loss: 0.3908
# Epoch 12/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 89.16% | Val Loss: 35.51
# 2025-06-14 17:39:48,281 - INFO - ✅ Validation complete | Val Acc: 89.16% | Val Loss: 35.51
# INFO:root:📊 Epoch 12 | Train Loss: 231.93 | Train Acc: 93.00% | Val Loss: 35.51 | Val Acc: 89.16% | Time: 83.34s
# 2025-06-14 17:39:48,285 - INFO - 📊 Epoch 12 | Train Loss: 231.93 | Train Acc: 93.00% | Val Loss: 35.51 | Val Acc: 89.16% | Time: 83.34s
# INFO:root:⚠️ No improvement for 3 epochs.
# 2025-06-14 17:39:48,287 - INFO - ⚠️ No improvement for 3 epochs.
# Epoch 13/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 13 - Batch 0 | Loss: 0.9490
# 2025-06-14 17:39:49,282 - INFO - 🧪 Epoch 13 - Batch 0 | Loss: 0.9490
# Epoch 13/30:  23%|██▎       | 100/434 [00:17<00:57,  5.84it/s]INFO:root:🧪 Epoch 13 - Batch 100 | Loss: 0.8562
# 2025-06-14 17:40:06,330 - INFO - 🧪 Epoch 13 - Batch 100 | Loss: 0.8562
# Epoch 13/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 13 - Batch 200 | Loss: 1.0914
# 2025-06-14 17:40:23,437 - INFO - 🧪 Epoch 13 - Batch 200 | Loss: 1.0914
# Epoch 13/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.85it/s]INFO:root:🧪 Epoch 13 - Batch 300 | Loss: 0.8692
# 2025-06-14 17:40:40,537 - INFO - 🧪 Epoch 13 - Batch 300 | Loss: 0.8692
# Epoch 13/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.87it/s]INFO:root:🧪 Epoch 13 - Batch 400 | Loss: 0.9740
# 2025-06-14 17:40:57,620 - INFO - 🧪 Epoch 13 - Batch 400 | Loss: 0.9740
# Epoch 13/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 89.82% | Val Loss: 35.88
# 2025-06-14 17:41:11,242 - INFO - ✅ Validation complete | Val Acc: 89.82% | Val Loss: 35.88
# INFO:root:📊 Epoch 13 | Train Loss: 227.95 | Train Acc: 93.51% | Val Loss: 35.88 | Val Acc: 89.82% | Time: 82.96s
# 2025-06-14 17:41:11,244 - INFO - 📊 Epoch 13 | Train Loss: 227.95 | Train Acc: 93.51% | Val Loss: 35.88 | Val Acc: 89.82% | Time: 82.96s
# INFO:root:⚠️ No improvement for 4 epochs.
# 2025-06-14 17:41:11,245 - INFO - ⚠️ No improvement for 4 epochs.
# Epoch 14/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 14 - Batch 0 | Loss: 0.3616
# 2025-06-14 17:41:12,264 - INFO - 🧪 Epoch 14 - Batch 0 | Loss: 0.3616
# Epoch 14/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 14 - Batch 100 | Loss: 0.4635
# 2025-06-14 17:41:29,306 - INFO - 🧪 Epoch 14 - Batch 100 | Loss: 0.4635
# Epoch 14/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 14 - Batch 200 | Loss: 0.3693
# 2025-06-14 17:41:46,350 - INFO - 🧪 Epoch 14 - Batch 200 | Loss: 0.3693
# Epoch 14/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.85it/s]INFO:root:🧪 Epoch 14 - Batch 300 | Loss: 0.4016
# 2025-06-14 17:42:03,443 - INFO - 🧪 Epoch 14 - Batch 300 | Loss: 0.4016
# Epoch 14/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.84it/s]INFO:root:🧪 Epoch 14 - Batch 400 | Loss: 0.3731
# 2025-06-14 17:42:20,519 - INFO - 🧪 Epoch 14 - Batch 400 | Loss: 0.3731
# Epoch 14/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.48% | Val Loss: 38.18
# 2025-06-14 17:42:34,197 - INFO - ✅ Validation complete | Val Acc: 90.48% | Val Loss: 38.18
# INFO:root:📊 Epoch 14 | Train Loss: 231.59 | Train Acc: 93.36% | Val Loss: 38.18 | Val Acc: 90.48% | Time: 82.95s
# 2025-06-14 17:42:34,199 - INFO - 📊 Epoch 14 | Train Loss: 231.59 | Train Acc: 93.36% | Val Loss: 38.18 | Val Acc: 90.48% | Time: 82.95s
# INFO:root:✅ New best model saved with Val Acc: 90.48%
# 2025-06-14 17:42:34,386 - INFO - ✅ New best model saved with Val Acc: 90.48%
# Epoch 15/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 15 - Batch 0 | Loss: 0.3548
# 2025-06-14 17:42:35,372 - INFO - 🧪 Epoch 15 - Batch 0 | Loss: 0.3548
# Epoch 15/30:  23%|██▎       | 100/434 [00:17<00:57,  5.78it/s]INFO:root:🧪 Epoch 15 - Batch 100 | Loss: 0.7662
# 2025-06-14 17:42:52,496 - INFO - 🧪 Epoch 15 - Batch 100 | Loss: 0.7662
# Epoch 15/30:  46%|████▌     | 200/434 [00:35<00:39,  5.85it/s]INFO:root:🧪 Epoch 15 - Batch 200 | Loss: 0.3617
# 2025-06-14 17:43:09,600 - INFO - 🧪 Epoch 15 - Batch 200 | Loss: 0.3617
# Epoch 15/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.84it/s]INFO:root:🧪 Epoch 15 - Batch 300 | Loss: 0.6508
# 2025-06-14 17:43:26,707 - INFO - 🧪 Epoch 15 - Batch 300 | Loss: 0.6508
# Epoch 15/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 15 - Batch 400 | Loss: 0.6018
# 2025-06-14 17:43:43,826 - INFO - 🧪 Epoch 15 - Batch 400 | Loss: 0.6018
# Epoch 15/30: 100%|██████████| 434/434 [01:14<00:00,  5.79it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.27% | Val Loss: 39.95
# 2025-06-14 17:43:57,368 - INFO - ✅ Validation complete | Val Acc: 90.27% | Val Loss: 39.95
# INFO:root:📊 Epoch 15 | Train Loss: 228.27 | Train Acc: 94.00% | Val Loss: 39.95 | Val Acc: 90.27% | Time: 82.98s
# 2025-06-14 17:43:57,370 - INFO - 📊 Epoch 15 | Train Loss: 228.27 | Train Acc: 94.00% | Val Loss: 39.95 | Val Acc: 90.27% | Time: 82.98s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:43:57,371 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 16/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 16 - Batch 0 | Loss: 0.9989
# 2025-06-14 17:43:58,307 - INFO - 🧪 Epoch 16 - Batch 0 | Loss: 0.9989
# Epoch 16/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 16 - Batch 100 | Loss: 0.9764
# 2025-06-14 17:44:15,364 - INFO - 🧪 Epoch 16 - Batch 100 | Loss: 0.9764
# Epoch 16/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 16 - Batch 200 | Loss: 0.3780
# 2025-06-14 17:44:32,411 - INFO - 🧪 Epoch 16 - Batch 200 | Loss: 0.3780
# Epoch 16/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.87it/s]INFO:root:🧪 Epoch 16 - Batch 300 | Loss: 0.3516
# 2025-06-14 17:44:49,445 - INFO - 🧪 Epoch 16 - Batch 300 | Loss: 0.3516
# Epoch 16/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.86it/s]INFO:root:🧪 Epoch 16 - Batch 400 | Loss: 0.4023
# 2025-06-14 17:45:06,540 - INFO - 🧪 Epoch 16 - Batch 400 | Loss: 0.4023
# Epoch 16/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.44% | Val Loss: 37.85
# 2025-06-14 17:45:20,142 - INFO - ✅ Validation complete | Val Acc: 90.44% | Val Loss: 37.85
# INFO:root:📊 Epoch 16 | Train Loss: 234.38 | Train Acc: 92.99% | Val Loss: 37.85 | Val Acc: 90.44% | Time: 82.77s
# 2025-06-14 17:45:20,145 - INFO - 📊 Epoch 16 | Train Loss: 234.38 | Train Acc: 92.99% | Val Loss: 37.85 | Val Acc: 90.44% | Time: 82.77s
# INFO:root:⚠️ No improvement for 2 epochs.
# 2025-06-14 17:45:20,147 - INFO - ⚠️ No improvement for 2 epochs.
# Epoch 17/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 17 - Batch 0 | Loss: 0.9695
# 2025-06-14 17:45:20,901 - INFO - 🧪 Epoch 17 - Batch 0 | Loss: 0.9695
# Epoch 17/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 17 - Batch 100 | Loss: 0.4669
# 2025-06-14 17:45:38,043 - INFO - 🧪 Epoch 17 - Batch 100 | Loss: 0.4669
# Epoch 17/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 17 - Batch 200 | Loss: 0.4409
# 2025-06-14 17:45:55,121 - INFO - 🧪 Epoch 17 - Batch 200 | Loss: 0.4409
# Epoch 17/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.86it/s]INFO:root:🧪 Epoch 17 - Batch 300 | Loss: 0.6596
# 2025-06-14 17:46:12,196 - INFO - 🧪 Epoch 17 - Batch 300 | Loss: 0.6596
# Epoch 17/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.85it/s]INFO:root:🧪 Epoch 17 - Batch 400 | Loss: 0.4296
# 2025-06-14 17:46:29,263 - INFO - 🧪 Epoch 17 - Batch 400 | Loss: 0.4296
# Epoch 17/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.42% | Val Loss: 37.10
# 2025-06-14 17:46:43,169 - INFO - ✅ Validation complete | Val Acc: 90.42% | Val Loss: 37.10
# INFO:root:📊 Epoch 17 | Train Loss: 227.64 | Train Acc: 94.02% | Val Loss: 37.10 | Val Acc: 90.42% | Time: 83.02s
# 2025-06-14 17:46:43,172 - INFO - 📊 Epoch 17 | Train Loss: 227.64 | Train Acc: 94.02% | Val Loss: 37.10 | Val Acc: 90.42% | Time: 83.02s
# INFO:root:⚠️ No improvement for 3 epochs.
# 2025-06-14 17:46:43,173 - INFO - ⚠️ No improvement for 3 epochs.
# Epoch 18/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 18 - Batch 0 | Loss: 0.3576
# 2025-06-14 17:46:44,087 - INFO - 🧪 Epoch 18 - Batch 0 | Loss: 0.3576
# Epoch 18/30:  23%|██▎       | 100/434 [00:17<00:57,  5.83it/s]INFO:root:🧪 Epoch 18 - Batch 100 | Loss: 0.4680
# 2025-06-14 17:47:01,195 - INFO - 🧪 Epoch 18 - Batch 100 | Loss: 0.4680
# Epoch 18/30:  46%|████▌     | 200/434 [00:34<00:40,  5.85it/s]INFO:root:🧪 Epoch 18 - Batch 200 | Loss: 0.3473
# 2025-06-14 17:47:18,271 - INFO - 🧪 Epoch 18 - Batch 200 | Loss: 0.3473
# Epoch 18/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.84it/s]INFO:root:🧪 Epoch 18 - Batch 300 | Loss: 0.3511
# 2025-06-14 17:47:35,337 - INFO - 🧪 Epoch 18 - Batch 300 | Loss: 0.3511
# Epoch 18/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.81it/s]INFO:root:🧪 Epoch 18 - Batch 400 | Loss: 0.4381
# 2025-06-14 17:47:52,455 - INFO - 🧪 Epoch 18 - Batch 400 | Loss: 0.4381
# Epoch 18/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.66% | Val Loss: 36.45
# 2025-06-14 17:48:06,128 - INFO - ✅ Validation complete | Val Acc: 90.66% | Val Loss: 36.45
# INFO:root:📊 Epoch 18 | Train Loss: 228.59 | Train Acc: 93.94% | Val Loss: 36.45 | Val Acc: 90.66% | Time: 82.96s
# 2025-06-14 17:48:06,131 - INFO - 📊 Epoch 18 | Train Loss: 228.59 | Train Acc: 93.94% | Val Loss: 36.45 | Val Acc: 90.66% | Time: 82.96s
# INFO:root:✅ New best model saved with Val Acc: 90.66%
# 2025-06-14 17:48:06,326 - INFO - ✅ New best model saved with Val Acc: 90.66%
# Epoch 19/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 19 - Batch 0 | Loss: 0.8753
# 2025-06-14 17:48:07,146 - INFO - 🧪 Epoch 19 - Batch 0 | Loss: 0.8753
# Epoch 19/30:  23%|██▎       | 100/434 [00:17<00:57,  5.84it/s]INFO:root:🧪 Epoch 19 - Batch 100 | Loss: 0.3575
# 2025-06-14 17:48:24,306 - INFO - 🧪 Epoch 19 - Batch 100 | Loss: 0.3575
# Epoch 19/30:  46%|████▌     | 200/434 [00:34<00:40,  5.85it/s]INFO:root:🧪 Epoch 19 - Batch 200 | Loss: 0.3529
# 2025-06-14 17:48:41,417 - INFO - 🧪 Epoch 19 - Batch 200 | Loss: 0.3529
# Epoch 19/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.84it/s]INFO:root:🧪 Epoch 19 - Batch 300 | Loss: 0.5792
# 2025-06-14 17:48:58,515 - INFO - 🧪 Epoch 19 - Batch 300 | Loss: 0.5792
# Epoch 19/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.85it/s]INFO:root:🧪 Epoch 19 - Batch 400 | Loss: 0.4016
# 2025-06-14 17:49:15,606 - INFO - 🧪 Epoch 19 - Batch 400 | Loss: 0.4016
# Epoch 19/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.85% | Val Loss: 36.63
# 2025-06-14 17:49:29,188 - INFO - ✅ Validation complete | Val Acc: 90.85% | Val Loss: 36.63
# INFO:root:📊 Epoch 19 | Train Loss: 218.98 | Train Acc: 94.93% | Val Loss: 36.63 | Val Acc: 90.85% | Time: 82.86s
# 2025-06-14 17:49:29,190 - INFO - 📊 Epoch 19 | Train Loss: 218.98 | Train Acc: 94.93% | Val Loss: 36.63 | Val Acc: 90.85% | Time: 82.86s
# INFO:root:✅ New best model saved with Val Acc: 90.85%
# 2025-06-14 17:49:29,403 - INFO - ✅ New best model saved with Val Acc: 90.85%
# Epoch 20/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 20 - Batch 0 | Loss: 0.4352
# 2025-06-14 17:49:30,320 - INFO - 🧪 Epoch 20 - Batch 0 | Loss: 0.4352
# Epoch 20/30:  23%|██▎       | 100/434 [00:17<00:57,  5.85it/s]INFO:root:🧪 Epoch 20 - Batch 100 | Loss: 0.8208
# 2025-06-14 17:49:47,411 - INFO - 🧪 Epoch 20 - Batch 100 | Loss: 0.8208
# Epoch 20/30:  46%|████▌     | 200/434 [00:34<00:40,  5.83it/s]INFO:root:🧪 Epoch 20 - Batch 200 | Loss: 0.4818
# 2025-06-14 17:50:04,511 - INFO - 🧪 Epoch 20 - Batch 200 | Loss: 0.4818
# Epoch 20/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.86it/s]INFO:root:🧪 Epoch 20 - Batch 300 | Loss: 0.3745
# 2025-06-14 17:50:21,633 - INFO - 🧪 Epoch 20 - Batch 300 | Loss: 0.3745
# Epoch 20/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.88it/s]INFO:root:🧪 Epoch 20 - Batch 400 | Loss: 0.4240
# 2025-06-14 17:50:38,707 - INFO - 🧪 Epoch 20 - Batch 400 | Loss: 0.4240
# Epoch 20/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.69% | Val Loss: 36.45
# 2025-06-14 17:50:52,498 - INFO - ✅ Validation complete | Val Acc: 90.69% | Val Loss: 36.45
# INFO:root:📊 Epoch 20 | Train Loss: 222.93 | Train Acc: 94.44% | Val Loss: 36.45 | Val Acc: 90.69% | Time: 83.09s
# 2025-06-14 17:50:52,500 - INFO - 📊 Epoch 20 | Train Loss: 222.93 | Train Acc: 94.44% | Val Loss: 36.45 | Val Acc: 90.69% | Time: 83.09s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:50:52,501 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 21/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 21 - Batch 0 | Loss: 0.4717
# 2025-06-14 17:50:53,294 - INFO - 🧪 Epoch 21 - Batch 0 | Loss: 0.4717
# Epoch 21/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 21 - Batch 100 | Loss: 0.3783
# 2025-06-14 17:51:10,410 - INFO - 🧪 Epoch 21 - Batch 100 | Loss: 0.3783
# Epoch 21/30:  46%|████▌     | 200/434 [00:34<00:40,  5.83it/s]INFO:root:🧪 Epoch 21 - Batch 200 | Loss: 0.3858
# 2025-06-14 17:51:27,498 - INFO - 🧪 Epoch 21 - Batch 200 | Loss: 0.3858
# Epoch 21/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.86it/s]INFO:root:🧪 Epoch 21 - Batch 300 | Loss: 0.3752
# 2025-06-14 17:51:44,588 - INFO - 🧪 Epoch 21 - Batch 300 | Loss: 0.3752
# Epoch 21/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.85it/s]INFO:root:🧪 Epoch 21 - Batch 400 | Loss: 0.6747
# 2025-06-14 17:52:01,681 - INFO - 🧪 Epoch 21 - Batch 400 | Loss: 0.6747
# Epoch 21/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.80% | Val Loss: 36.97
# 2025-06-14 17:52:15,491 - INFO - ✅ Validation complete | Val Acc: 90.80% | Val Loss: 36.97
# INFO:root:📊 Epoch 21 | Train Loss: 222.30 | Train Acc: 94.25% | Val Loss: 36.97 | Val Acc: 90.80% | Time: 82.99s
# 2025-06-14 17:52:15,493 - INFO - 📊 Epoch 21 | Train Loss: 222.30 | Train Acc: 94.25% | Val Loss: 36.97 | Val Acc: 90.80% | Time: 82.99s
# INFO:root:⚠️ No improvement for 2 epochs.
# 2025-06-14 17:52:15,496 - INFO - ⚠️ No improvement for 2 epochs.
# Epoch 22/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 22 - Batch 0 | Loss: 0.3573
# 2025-06-14 17:52:16,264 - INFO - 🧪 Epoch 22 - Batch 0 | Loss: 0.3573
# Epoch 22/30:  23%|██▎       | 100/434 [00:17<00:57,  5.84it/s]INFO:root:🧪 Epoch 22 - Batch 100 | Loss: 0.3532
# 2025-06-14 17:52:33,513 - INFO - 🧪 Epoch 22 - Batch 100 | Loss: 0.3532
# Epoch 22/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 22 - Batch 200 | Loss: 0.3578
# 2025-06-14 17:52:50,605 - INFO - 🧪 Epoch 22 - Batch 200 | Loss: 0.3578
# Epoch 22/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.84it/s]INFO:root:🧪 Epoch 22 - Batch 300 | Loss: 0.3550
# 2025-06-14 17:53:07,714 - INFO - 🧪 Epoch 22 - Batch 300 | Loss: 0.3550
# Epoch 22/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 22 - Batch 400 | Loss: 0.4852
# 2025-06-14 17:53:24,812 - INFO - 🧪 Epoch 22 - Batch 400 | Loss: 0.4852
# Epoch 22/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.05% | Val Loss: 36.81
# 2025-06-14 17:53:38,403 - INFO - ✅ Validation complete | Val Acc: 91.05% | Val Loss: 36.81
# INFO:root:📊 Epoch 22 | Train Loss: 225.10 | Train Acc: 94.50% | Val Loss: 36.81 | Val Acc: 91.05% | Time: 82.91s
# 2025-06-14 17:53:38,405 - INFO - 📊 Epoch 22 | Train Loss: 225.10 | Train Acc: 94.50% | Val Loss: 36.81 | Val Acc: 91.05% | Time: 82.91s
# INFO:root:✅ New best model saved with Val Acc: 91.05%
# 2025-06-14 17:53:38,603 - INFO - ✅ New best model saved with Val Acc: 91.05%
# Epoch 23/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 23 - Batch 0 | Loss: 0.8354
# 2025-06-14 17:53:39,584 - INFO - 🧪 Epoch 23 - Batch 0 | Loss: 0.8354
# Epoch 23/30:  23%|██▎       | 100/434 [00:17<00:57,  5.86it/s]INFO:root:🧪 Epoch 23 - Batch 100 | Loss: 0.3449
# 2025-06-14 17:53:56,674 - INFO - 🧪 Epoch 23 - Batch 100 | Loss: 0.3449
# Epoch 23/30:  46%|████▌     | 200/434 [00:34<00:40,  5.85it/s]INFO:root:🧪 Epoch 23 - Batch 200 | Loss: 0.3662
# 2025-06-14 17:54:13,772 - INFO - 🧪 Epoch 23 - Batch 200 | Loss: 0.3662
# Epoch 23/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.85it/s]INFO:root:🧪 Epoch 23 - Batch 300 | Loss: 0.3454
# 2025-06-14 17:54:30,858 - INFO - 🧪 Epoch 23 - Batch 300 | Loss: 0.3454
# Epoch 23/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.85it/s]INFO:root:🧪 Epoch 23 - Batch 400 | Loss: 0.3664
# 2025-06-14 17:54:47,946 - INFO - 🧪 Epoch 23 - Batch 400 | Loss: 0.3664
# Epoch 23/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 90.87% | Val Loss: 36.31
# 2025-06-14 17:55:01,611 - INFO - ✅ Validation complete | Val Acc: 90.87% | Val Loss: 36.31
# INFO:root:📊 Epoch 23 | Train Loss: 223.55 | Train Acc: 94.38% | Val Loss: 36.31 | Val Acc: 90.87% | Time: 83.01s
# 2025-06-14 17:55:01,614 - INFO - 📊 Epoch 23 | Train Loss: 223.55 | Train Acc: 94.38% | Val Loss: 36.31 | Val Acc: 90.87% | Time: 83.01s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:55:01,615 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 24/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 24 - Batch 0 | Loss: 0.5536
# 2025-06-14 17:55:02,518 - INFO - 🧪 Epoch 24 - Batch 0 | Loss: 0.5536
# Epoch 24/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 24 - Batch 100 | Loss: 0.8115
# 2025-06-14 17:55:19,620 - INFO - 🧪 Epoch 24 - Batch 100 | Loss: 0.8115
# Epoch 24/30:  46%|████▌     | 200/434 [00:34<00:40,  5.84it/s]INFO:root:🧪 Epoch 24 - Batch 200 | Loss: 0.8081
# 2025-06-14 17:55:36,720 - INFO - 🧪 Epoch 24 - Batch 200 | Loss: 0.8081
# Epoch 24/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.86it/s]INFO:root:🧪 Epoch 24 - Batch 300 | Loss: 0.3593
# 2025-06-14 17:55:53,798 - INFO - 🧪 Epoch 24 - Batch 300 | Loss: 0.3593
# Epoch 24/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.84it/s]INFO:root:🧪 Epoch 24 - Batch 400 | Loss: 0.3563
# 2025-06-14 17:56:10,943 - INFO - 🧪 Epoch 24 - Batch 400 | Loss: 0.3563
# Epoch 24/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.09% | Val Loss: 35.97
# 2025-06-14 17:56:24,638 - INFO - ✅ Validation complete | Val Acc: 91.09% | Val Loss: 35.97
# INFO:root:📊 Epoch 24 | Train Loss: 220.24 | Train Acc: 94.60% | Val Loss: 35.97 | Val Acc: 91.09% | Time: 83.02s
# 2025-06-14 17:56:24,640 - INFO - 📊 Epoch 24 | Train Loss: 220.24 | Train Acc: 94.60% | Val Loss: 35.97 | Val Acc: 91.09% | Time: 83.02s
# INFO:root:✅ New best model saved with Val Acc: 91.09%
# 2025-06-14 17:56:24,837 - INFO - ✅ New best model saved with Val Acc: 91.09%
# Epoch 25/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 25 - Batch 0 | Loss: 0.8726
# 2025-06-14 17:56:25,863 - INFO - 🧪 Epoch 25 - Batch 0 | Loss: 0.8726
# Epoch 25/30:  23%|██▎       | 100/434 [00:17<00:56,  5.86it/s]INFO:root:🧪 Epoch 25 - Batch 100 | Loss: 0.3440
# 2025-06-14 17:56:42,929 - INFO - 🧪 Epoch 25 - Batch 100 | Loss: 0.3440
# Epoch 25/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 25 - Batch 200 | Loss: 0.6907
# 2025-06-14 17:56:59,997 - INFO - 🧪 Epoch 25 - Batch 200 | Loss: 0.6907
# Epoch 25/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.86it/s]INFO:root:🧪 Epoch 25 - Batch 300 | Loss: 0.4270
# 2025-06-14 17:57:17,039 - INFO - 🧪 Epoch 25 - Batch 300 | Loss: 0.4270
# Epoch 25/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 25 - Batch 400 | Loss: 0.3470
# 2025-06-14 17:57:34,106 - INFO - 🧪 Epoch 25 - Batch 400 | Loss: 0.3470
# Epoch 25/30: 100%|██████████| 434/434 [01:14<00:00,  5.81it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.20% | Val Loss: 36.19
# 2025-06-14 17:57:47,980 - INFO - ✅ Validation complete | Val Acc: 91.20% | Val Loss: 36.19
# INFO:root:📊 Epoch 25 | Train Loss: 217.90 | Train Acc: 95.32% | Val Loss: 36.19 | Val Acc: 91.20% | Time: 83.14s
# 2025-06-14 17:57:47,983 - INFO - 📊 Epoch 25 | Train Loss: 217.90 | Train Acc: 95.32% | Val Loss: 36.19 | Val Acc: 91.20% | Time: 83.14s
# INFO:root:✅ New best model saved with Val Acc: 91.20%
# 2025-06-14 17:57:48,181 - INFO - ✅ New best model saved with Val Acc: 91.20%
# Epoch 26/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 26 - Batch 0 | Loss: 0.3570
# 2025-06-14 17:57:49,103 - INFO - 🧪 Epoch 26 - Batch 0 | Loss: 0.3570
# Epoch 26/30:  23%|██▎       | 100/434 [00:17<00:56,  5.91it/s]INFO:root:🧪 Epoch 26 - Batch 100 | Loss: 0.4011
# 2025-06-14 17:58:06,077 - INFO - 🧪 Epoch 26 - Batch 100 | Loss: 0.4011
# Epoch 26/30:  46%|████▌     | 200/434 [00:34<00:39,  5.89it/s]INFO:root:🧪 Epoch 26 - Batch 200 | Loss: 0.3443
# 2025-06-14 17:58:23,036 - INFO - 🧪 Epoch 26 - Batch 200 | Loss: 0.3443
# Epoch 26/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.87it/s]INFO:root:🧪 Epoch 26 - Batch 300 | Loss: 0.8129
# 2025-06-14 17:58:40,057 - INFO - 🧪 Epoch 26 - Batch 300 | Loss: 0.8129
# Epoch 26/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.87it/s]INFO:root:🧪 Epoch 26 - Batch 400 | Loss: 0.3563
# 2025-06-14 17:58:57,108 - INFO - 🧪 Epoch 26 - Batch 400 | Loss: 0.3563
# Epoch 26/30: 100%|██████████| 434/434 [01:14<00:00,  5.84it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.13% | Val Loss: 36.45
# 2025-06-14 17:59:10,616 - INFO - ✅ Validation complete | Val Acc: 91.13% | Val Loss: 36.45
# INFO:root:📊 Epoch 26 | Train Loss: 225.01 | Train Acc: 94.60% | Val Loss: 36.45 | Val Acc: 91.13% | Time: 82.43s
# 2025-06-14 17:59:10,619 - INFO - 📊 Epoch 26 | Train Loss: 225.01 | Train Acc: 94.60% | Val Loss: 36.45 | Val Acc: 91.13% | Time: 82.43s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 17:59:10,620 - INFO - ⚠️ No improvement for 1 epochs.
# Epoch 27/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 27 - Batch 0 | Loss: 0.8278
# 2025-06-14 17:59:11,646 - INFO - 🧪 Epoch 27 - Batch 0 | Loss: 0.8278
# Epoch 27/30:  23%|██▎       | 100/434 [00:17<00:56,  5.88it/s]INFO:root:🧪 Epoch 27 - Batch 100 | Loss: 0.3738
# 2025-06-14 17:59:28,660 - INFO - 🧪 Epoch 27 - Batch 100 | Loss: 0.3738
# Epoch 27/30:  46%|████▌     | 200/434 [00:34<00:39,  5.87it/s]INFO:root:🧪 Epoch 27 - Batch 200 | Loss: 0.3464
# 2025-06-14 17:59:45,664 - INFO - 🧪 Epoch 27 - Batch 200 | Loss: 0.3464
# Epoch 27/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.84it/s]INFO:root:🧪 Epoch 27 - Batch 300 | Loss: 0.3600
# 2025-06-14 18:00:02,722 - INFO - 🧪 Epoch 27 - Batch 300 | Loss: 0.3600
# Epoch 27/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.86it/s]INFO:root:🧪 Epoch 27 - Batch 400 | Loss: 0.3536
# 2025-06-14 18:00:19,784 - INFO - 🧪 Epoch 27 - Batch 400 | Loss: 0.3536
# Epoch 27/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.24% | Val Loss: 36.37
# 2025-06-14 18:00:34,097 - INFO - ✅ Validation complete | Val Acc: 91.24% | Val Loss: 36.37
# INFO:root:📊 Epoch 27 | Train Loss: 215.07 | Train Acc: 95.41% | Val Loss: 36.37 | Val Acc: 91.24% | Time: 83.48s
# 2025-06-14 18:00:34,100 - INFO - 📊 Epoch 27 | Train Loss: 215.07 | Train Acc: 95.41% | Val Loss: 36.37 | Val Acc: 91.24% | Time: 83.48s
# INFO:root:✅ New best model saved with Val Acc: 91.24%
# 2025-06-14 18:00:34,289 - INFO - ✅ New best model saved with Val Acc: 91.24%
# Epoch 28/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 28 - Batch 0 | Loss: 0.3468
# 2025-06-14 18:00:35,258 - INFO - 🧪 Epoch 28 - Batch 0 | Loss: 0.3468
# Epoch 28/30:  23%|██▎       | 100/434 [00:17<00:56,  5.88it/s]INFO:root:🧪 Epoch 28 - Batch 100 | Loss: 0.3512
# 2025-06-14 18:00:52,231 - INFO - 🧪 Epoch 28 - Batch 100 | Loss: 0.3512
# Epoch 28/30:  46%|████▌     | 200/434 [00:34<00:39,  5.86it/s]INFO:root:🧪 Epoch 28 - Batch 200 | Loss: 0.3494
# 2025-06-14 18:01:09,233 - INFO - 🧪 Epoch 28 - Batch 200 | Loss: 0.3494
# Epoch 28/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.88it/s]INFO:root:🧪 Epoch 28 - Batch 300 | Loss: 0.4865
# 2025-06-14 18:01:26,308 - INFO - 🧪 Epoch 28 - Batch 300 | Loss: 0.4865
# Epoch 28/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.80it/s]INFO:root:🧪 Epoch 28 - Batch 400 | Loss: 0.3523
# 2025-06-14 18:01:43,390 - INFO - 🧪 Epoch 28 - Batch 400 | Loss: 0.3523
# Epoch 28/30: 100%|██████████| 434/434 [01:14<00:00,  5.82it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.28% | Val Loss: 36.34
# 2025-06-14 18:01:57,775 - INFO - ✅ Validation complete | Val Acc: 91.28% | Val Loss: 36.34
# INFO:root:📊 Epoch 28 | Train Loss: 214.75 | Train Acc: 95.21% | Val Loss: 36.34 | Val Acc: 91.28% | Time: 83.49s
# 2025-06-14 18:01:57,778 - INFO - 📊 Epoch 28 | Train Loss: 214.75 | Train Acc: 95.21% | Val Loss: 36.34 | Val Acc: 91.28% | Time: 83.49s
# INFO:root:✅ New best model saved with Val Acc: 91.28%
# 2025-06-14 18:01:57,966 - INFO - ✅ New best model saved with Val Acc: 91.28%
# Epoch 29/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 29 - Batch 0 | Loss: 0.3556
# 2025-06-14 18:01:58,991 - INFO - 🧪 Epoch 29 - Batch 0 | Loss: 0.3556
# Epoch 29/30:  23%|██▎       | 100/434 [00:17<00:56,  5.87it/s]INFO:root:🧪 Epoch 29 - Batch 100 | Loss: 0.8198
# 2025-06-14 18:02:16,015 - INFO - 🧪 Epoch 29 - Batch 100 | Loss: 0.8198
# Epoch 29/30:  46%|████▌     | 200/434 [00:34<00:39,  5.85it/s]INFO:root:🧪 Epoch 29 - Batch 200 | Loss: 0.3516
# 2025-06-14 18:02:33,082 - INFO - 🧪 Epoch 29 - Batch 200 | Loss: 0.3516
# Epoch 29/30:  69%|██████▉   | 300/434 [00:52<00:22,  5.86it/s]INFO:root:🧪 Epoch 29 - Batch 300 | Loss: 0.3708
# 2025-06-14 18:02:50,201 - INFO - 🧪 Epoch 29 - Batch 300 | Loss: 0.3708
# Epoch 29/30:  92%|█████████▏| 400/434 [01:09<00:05,  5.86it/s]INFO:root:🧪 Epoch 29 - Batch 400 | Loss: 0.5556
# 2025-06-14 18:03:07,283 - INFO - 🧪 Epoch 29 - Batch 400 | Loss: 0.5556
# Epoch 29/30: 100%|██████████| 434/434 [01:14<00:00,  5.80it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.38% | Val Loss: 36.09
# 2025-06-14 18:03:21,230 - INFO - ✅ Validation complete | Val Acc: 91.38% | Val Loss: 36.09
# INFO:root:📊 Epoch 29 | Train Loss: 215.03 | Train Acc: 95.81% | Val Loss: 36.09 | Val Acc: 91.38% | Time: 83.26s
# 2025-06-14 18:03:21,233 - INFO - 📊 Epoch 29 | Train Loss: 215.03 | Train Acc: 95.81% | Val Loss: 36.09 | Val Acc: 91.38% | Time: 83.26s
# INFO:root:✅ New best model saved with Val Acc: 91.38%
# 2025-06-14 18:03:21,423 - INFO - ✅ New best model saved with Val Acc: 91.38%
# Epoch 30/30:   0%|          | 0/434 [00:00<?, ?it/s]INFO:root:🧪 Epoch 30 - Batch 0 | Loss: 0.3496
# 2025-06-14 18:03:22,418 - INFO - 🧪 Epoch 30 - Batch 0 | Loss: 0.3496
# Epoch 30/30:  23%|██▎       | 100/434 [00:17<00:56,  5.88it/s]INFO:root:🧪 Epoch 30 - Batch 100 | Loss: 0.3461
# 2025-06-14 18:03:39,393 - INFO - 🧪 Epoch 30 - Batch 100 | Loss: 0.3461
# Epoch 30/30:  46%|████▌     | 200/434 [00:34<00:39,  5.88it/s]INFO:root:🧪 Epoch 30 - Batch 200 | Loss: 0.3485
# 2025-06-14 18:03:56,393 - INFO - 🧪 Epoch 30 - Batch 200 | Loss: 0.3485
# Epoch 30/30:  69%|██████▉   | 300/434 [00:51<00:22,  5.89it/s]INFO:root:🧪 Epoch 30 - Batch 300 | Loss: 0.6251
# 2025-06-14 18:04:13,421 - INFO - 🧪 Epoch 30 - Batch 300 | Loss: 0.6251
# Epoch 30/30:  92%|█████████▏| 400/434 [01:08<00:05,  5.86it/s]INFO:root:🧪 Epoch 30 - Batch 400 | Loss: 0.3446
# 2025-06-14 18:04:30,427 - INFO - 🧪 Epoch 30 - Batch 400 | Loss: 0.3446
# Epoch 30/30: 100%|██████████| 434/434 [01:14<00:00,  5.83it/s]
# INFO:root:✅ Validation complete | Val Acc: 91.29% | Val Loss: 36.41
# 2025-06-14 18:04:44,471 - INFO - ✅ Validation complete | Val Acc: 91.29% | Val Loss: 36.41
# INFO:root:📊 Epoch 30 | Train Loss: 214.39 | Train Acc: 95.33% | Val Loss: 36.41 | Val Acc: 91.29% | Time: 83.05s
# 2025-06-14 18:04:44,474 - INFO - 📊 Epoch 30 | Train Loss: 214.39 | Train Acc: 95.33% | Val Loss: 36.41 | Val Acc: 91.29% | Time: 83.05s
# INFO:root:⚠️ No improvement for 1 epochs.
# 2025-06-14 18:04:44,476 - INFO - ⚠️ No improvement for 1 epochs.
# INFO:root:🏁 Training complete. Best accuracy: 91.38%
# 2025-06-14 18:04:44,479 - INFO - 🏁 Training complete. Best accuracy: 91.38%
# INFO:root:📱 Converting models for mobile deployment...
# 2025-06-14 18:04:44,481 - INFO - 📱 Converting models for mobile deployment...
# INFO:root:🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:04:44,482 - INFO - 🔄 Converting PyTorch to ONNX...
# ERROR:root:❌ Error during mobile conversion: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
# 2025-06-14 18:04:44,645 - ERROR - ❌ Error during mobile conversion: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor
# INFO:root:
# 📦 Required packages for mobile conversion:
# 2025-06-14 18:04:44,647 - INFO -
# 📦 Required packages for mobile conversion:
# INFO:root:pip install onnx onnx2tf tensorflow coremltools
# 2025-06-14 18:04:44,649 - INFO - pip install onnx onnx2tf tensorflow coremltools
# INFO:root:
# 🏆 Training completed with best accuracy: 91.38%
# 2025-06-14 18:04:44,654 - INFO -
# 🏆 Training completed with best accuracy: 91.38%
# INFO:root:📱 Mobile models ready for deployment!
# 2025-06-14 18:04:44,655 - INFO - 📱 Mobile models ready for deployment!

# %%
import os
import json
import torch
import torch.nn as nn
import timm
import numpy as np
import logging
from datetime import datetime
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

# Setup logging
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
log_file = f"model_conversion_{timestamp}.log"
logging.basicConfig(
    filename=log_file,
    filemode="w",
    format="%(asctime)s - %(levelname)s - %(message)s",
    level=logging.INFO
)
console = logging.StreamHandler()
console.setLevel(logging.INFO)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
console.setFormatter(formatter)
logging.getLogger().addHandler(console)

# ───────────── CONFIG ─────────────
IMG_SIZE = 224
NUM_CLASSES = 4
MODEL_NAME = "convnext_tiny"
MODEL_PATH = "best_emotion_model.pt"

# Define the same model architecture
class EmotionClassifier(nn.Module):
    def __init__(self, model_name, num_classes):
        super(EmotionClassifier, self).__init__()
        self.backbone = timm.create_model(model_name, pretrained=True, num_classes=0)
        self.classifier = nn.Linear(self.backbone.num_features, num_classes)
        
    def forward(self, x):
        features = self.backbone(x)
        return self.classifier(features)

def load_trained_model():
    """Load the trained PyTorch model"""
    logging.info("📥 Loading trained PyTorch model...")
    
    # Initialize model
    model = EmotionClassifier(MODEL_NAME, NUM_CLASSES)
    
    # Load state dict and move to CPU to avoid device mismatch
    state_dict = torch.load(MODEL_PATH, map_location='cpu')
    model.load_state_dict(state_dict)
    model.eval()
    
    logging.info("✅ Model loaded successfully")
    return model

def save_pytorch_model(model):
    """Save optimized PyTorch model for deployment"""
    logging.info("💾 Saving optimized PyTorch model...")
    
    # Save full model (not just state_dict)
    torch.save(model, "emotion_classifier_full.pt")
    
    # Save state dict on CPU
    torch.save(model.state_dict(), "emotion_classifier_weights.pt")
    
    # Save TorchScript version
    dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
    traced_model = torch.jit.trace(model, dummy_input)
    torch.jit.save(traced_model, "emotion_classifier_torchscript.pt")
    
    logging.info("✅ PyTorch models saved")
    return traced_model

def convert_to_onnx(model):
    """Convert PyTorch model to ONNX"""
    logging.info("🔄 Converting PyTorch to ONNX...")
    
    try:
        # Create dummy input
        dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
        
        # Export to ONNX
        onnx_path = "emotion_model.onnx"
        torch.onnx.export(
            model,
            dummy_input,
            onnx_path,
            export_params=True,
            opset_version=11,
            do_constant_folding=True,
            input_names=['input'],
            output_names=['output'],
            dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}},
            verbose=False
        )
        
        # Verify ONNX model
        import onnx
        onnx_model = onnx.load(onnx_path)
        onnx.checker.check_model(onnx_model)
        
        model_size = os.path.getsize(onnx_path) / (1024 * 1024)
        logging.info(f"✅ ONNX model saved: {onnx_path} ({model_size:.2f} MB)")
        return onnx_path
        
    except ImportError:
        logging.error("❌ ONNX not installed. Install with: pip install onnx")
        return None
    except Exception as e:
        logging.error(f"❌ ONNX conversion failed: {e}")
        return None

def convert_to_tflite_direct(model):
    """Direct PyTorch to mobile conversion (fallback method)"""
    logging.info("🔄 Creating mobile-optimized PyTorch model...")
    
    try:
        # Ensure model is on CPU
        model_cpu = model.cpu()
        model_cpu.eval()
        
        dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
        
        with torch.no_grad():
            traced_model = torch.jit.trace(model_cpu, dummy_input)
            
            # Try mobile optimization if available
            try:
                from torch.utils.mobile_optimizer import optimize_for_mobile
                optimized_model = optimize_for_mobile(traced_model)
                
                # Save mobile-optimized PyTorch model
                mobile_path = "emotion_model_mobile.pt"
                optimized_model._save_for_lite_interpreter(mobile_path)
                
                model_size = os.path.getsize(mobile_path) / (1024 * 1024)
                logging.info(f"✅ Mobile PyTorch model saved: {mobile_path} ({model_size:.2f} MB)")
                
            except ImportError:
                # Fallback: save regular TorchScript model for mobile
                mobile_path = "emotion_model_mobile.pt"
                torch.jit.save(traced_model, mobile_path)
                
                model_size = os.path.getsize(mobile_path) / (1024 * 1024)
                logging.info(f"✅ Mobile PyTorch model (fallback) saved: {mobile_path} ({model_size:.2f} MB)")
        
        # Provide guidance for TFLite conversion
        logging.info("ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow")
        logging.info("ℹ️ Then re-run to get .tflite models for Android")
        
        return [mobile_path]
        
    except Exception as e:
        logging.error(f"❌ Mobile PyTorch conversion failed: {e}")
        return None

def convert_tflite_quantized(tf_model_dir):
    """Create quantized TFLite model"""
    logging.info("🔄 Creating quantized TFLite model...")
    
    try:
        import tensorflow as tf
        
        # Representative dataset for quantization
        def representative_data_gen():
            for _ in range(100):
                # Generate representative data (random images)
                data = np.random.random((1, IMG_SIZE, IMG_SIZE, 3)).astype(np.float32)
                # Apply ImageNet normalization
                mean = np.array([0.485, 0.456, 0.406])
                std = np.array([0.229, 0.224, 0.225])
                data = (data - mean) / std
                yield [data]
        
        converter = tf.lite.TFLiteConverter.from_saved_model(tf_model_dir)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        converter.representative_dataset = representative_data_gen
        converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
        converter.inference_input_type = tf.uint8
        converter.inference_output_type = tf.uint8
        
        tflite_quantized = converter.convert()
        
        quantized_path = "emotion_model_quantized.tflite"
        with open(quantized_path, 'wb') as f:
            f.write(tflite_quantized)
        
        model_size = len(tflite_quantized) / (1024 * 1024)
        logging.info(f"✅ TFLite (Quantized) model saved: {quantized_path} ({model_size:.2f} MB)")
        
        return quantized_path
        
    except Exception as e:
        logging.error(f"⚠️ Quantized TFLite conversion failed: {e}")
        return None

def convert_to_tflite(onnx_path):
    """Convert ONNX to TensorFlow Lite"""
    logging.info("🔄 Converting ONNX to TensorFlow Lite...")
    
    try:
        import onnx2tf
        import tensorflow as tf
        
        # Convert ONNX to TensorFlow SavedModel
        tf_model_dir = "emotion_tf_model"
        onnx2tf.convert(
            input_onnx_file_path=onnx_path,
            output_folder_path=tf_model_dir,
            copy_onnx_input_output_names_to_tflite=True,
            non_verbose=True
        )
        
        # Convert SavedModel to TFLite (Float32)
        converter = tf.lite.TFLiteConverter.from_saved_model(tf_model_dir)
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
        
        tflite_model = converter.convert()
        
        # Save float32 model
        tflite_path = "emotion_model_float32.tflite"
        with open(tflite_path, 'wb') as f:
            f.write(tflite_model)
        
        model_size = len(tflite_model) / (1024 * 1024)
        logging.info(f"✅ TFLite (Float32) model saved: {tflite_path} ({model_size:.2f} MB)")
        
        # Try quantized version
        try:
            quantized_path = convert_tflite_quantized(tf_model_dir)
            return [tflite_path, quantized_path] if quantized_path else [tflite_path]
        except:
            return [tflite_path]
        
    except ImportError:
        logging.error("❌ onnx2tf or tensorflow not installed. Install with: pip install onnx2tf tensorflow")
        return None
    except Exception as e:
        logging.error(f"❌ TFLite conversion failed: {e}")
        return None

def convert_to_coreml(model):
    """Convert PyTorch model to Core ML (.mlpackage)"""
    logging.info("🔄 Converting PyTorch to Core ML (.mlpackage)...")
    
    try:
        import coremltools as ct
        
        # Load class names if available
        class_names = ["angry", "happy", "neutral", "sad"]  # Default
        try:
            with open('class_mapping.json', 'r') as f:
                class_mapping = json.load(f)
                class_names = [class_mapping[str(i)] for i in range(len(class_mapping))]
        except:
            logging.warning("⚠️ class_mapping.json not found, using default class names")
        
        # Create dummy input - ensure it's on CPU
        dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
        
        # Ensure model is on CPU and in eval mode
        model_cpu = model.cpu()
        model_cpu.eval()
        
        # Trace the model with CPU tensors
        with torch.no_grad():
            traced_model = torch.jit.trace(model_cpu, dummy_input)
        
        # Try simpler conversion first (without image preprocessing)
        try:
            mlmodel = ct.convert(
                traced_model,
                inputs=[ct.TensorType(name="input", shape=dummy_input.shape)],
                outputs=[ct.TensorType(name="output")],
                minimum_deployment_target=ct.target.iOS13,  # Use older target for better compatibility
                compute_units=ct.ComputeUnit.CPU_ONLY  # Use CPU only to avoid compatibility issues
            )
            
            # Save as .mlpackage
            mlpackage_path = "EmotionClassifier.mlpackage"
            mlmodel.save(mlpackage_path)
            
            # Set model metadata after saving
            mlmodel.short_description = "Emotion Classification Model"
            mlmodel.author = "AI Team"
            mlmodel.license = "MIT"
            mlmodel.version = "1.0.0"
            
            logging.info(f"✅ Core ML model saved: {mlpackage_path}")
            logging.info("ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)")
            return mlpackage_path
            
        except Exception as e:
            logging.warning(f"⚠️ Standard Core ML conversion failed: {e}")
            logging.info("🔄 Trying alternative Core ML conversion...")
            
            # Try with different settings
            mlmodel = ct.convert(
                traced_model,
                inputs=[ct.TensorType(name="input", shape=(1, 3, IMG_SIZE, IMG_SIZE))],
                minimum_deployment_target=ct.target.iOS13,
                compute_units=ct.ComputeUnit.CPU_ONLY
            )
            
            mlpackage_path = "EmotionClassifier_simple.mlpackage" 
            mlmodel.save(mlpackage_path)
            
            logging.info(f"✅ Alternative Core ML model saved: {mlpackage_path}")
            return mlpackage_path
        
    except ImportError:
        logging.error("❌ coremltools not installed. Install with: pip install coremltools")
        return None
    except Exception as e:
        logging.error(f"❌ Core ML conversion failed: {e}")
        logging.info("💡 Try: pip install --upgrade coremltools")
        return None

def create_deployment_metadata():
    """Create metadata files for deployment"""
    logging.info("📝 Creating deployment metadata...")
    
    # Model metadata
    metadata = {
        "model_info": {
            "name": "Emotion Classifier",
            "version": "1.0.0",
            "architecture": MODEL_NAME,
            "input_size": [IMG_SIZE, IMG_SIZE],
            "num_classes": NUM_CLASSES,
            "accuracy": "91.38%"  # Update with actual best accuracy
        },
        "preprocessing": {
            "resize": [IMG_SIZE, IMG_SIZE],
            "normalization": {
                "mean": [0.485, 0.456, 0.406],
                "std": [0.229, 0.224, 0.225]
            },
            "color_format": "RGB"
        },
        "classes": {
            "0": "angry",
            "1": "happy", 
            "2": "neutral",
            "3": "sad"
        },
        "deployment": {
            "android": {
                "model_file": "emotion_model_float32.tflite",
                "quantized_file": "emotion_model_quantized.tflite",
                "mobile_pytorch": "emotion_model_mobile.pt",
                "framework": "TensorFlow Lite / PyTorch Mobile"
            },
            "ios": {
                "model_file": "EmotionClassifier.mlpackage",
                "framework": "Core ML"
            },
            "server": {
                "model_file": "emotion_classifier_torchscript.pt",
                "onnx_file": "emotion_model.onnx",
                "framework": "PyTorch/ONNX"
            }
        }
    }
    
    with open('deployment_metadata.json', 'w') as f:
        json.dump(metadata, f, indent=2)
    
    # Create class mapping file
    class_mapping = {str(i): name for i, name in enumerate(["angry", "happy", "neutral", "sad"])}
    with open('class_mapping.json', 'w') as f:
        json.dump(class_mapping, f, indent=2)
    
    # Create deployment summary
    summary = """# Emotion Classification Model - Deployment Summary

## Model Information
- **Architecture**: ConvNeXt-Tiny
- **Input Size**: 224x224 RGB
- **Classes**: 4 (angry, happy, neutral, sad)
- **Accuracy**: 91.38%

## Generated Files

### PyTorch Models
- `emotion_classifier_full.pt` - Complete model for Python deployment
- `emotion_classifier_weights.pt` - Model weights only
- `emotion_classifier_torchscript.pt` - TorchScript for production
- `emotion_model_mobile.pt` - Mobile-optimized PyTorch

### Mobile Models
- `emotion_model_float32.tflite` - Android TensorFlow Lite (Float32)
- `emotion_model_quantized.tflite` - Android TensorFlow Lite (Quantized, smaller)
- `EmotionClassifier.mlpackage` - iOS Core ML

### Cross-Platform
- `emotion_model.onnx` - ONNX format for various frameworks

### Metadata
- `deployment_metadata.json` - Complete model information
- `class_mapping.json` - Class index to name mapping

## Preprocessing Required
All models expect input images to be:
1. Resized to 224x224
2. Normalized with ImageNet statistics:
   - Mean: [0.485, 0.456, 0.406]
   - Std: [0.229, 0.224, 0.225]
3. RGB color format

## Integration Notes
- TensorFlow Lite models are optimized for Android deployment
- Core ML model includes preprocessing and is ready for iOS
- ONNX model can be used with various inference engines
- TorchScript model is ideal for Python/server deployment
- Mobile PyTorch model works on both Android and iOS with PyTorch Mobile
"""
    
    with open('DEPLOYMENT_SUMMARY.md', 'w') as f:
        f.write(summary)
    
    logging.info("✅ Deployment metadata created")

def test_model_inference(model):
    """Test the converted models with a dummy input"""
    logging.info("🧪 Testing model inference...")
    
    try:
        # Test PyTorch model
        dummy_input = torch.randn(1, 3, IMG_SIZE, IMG_SIZE)
        with torch.no_grad():
            output = model(dummy_input)
            probabilities = torch.softmax(output, dim=1)
            predicted_class = torch.argmax(probabilities, dim=1).item()
        
        logging.info(f"✅ PyTorch inference test passed - Predicted class: {predicted_class}")
        
        # Test ONNX if available
        if os.path.exists("emotion_model.onnx"):
            try:
                import onnxruntime as ort
                session = ort.InferenceSession("emotion_model.onnx")
                input_name = session.get_inputs()[0].name
                output_name = session.get_outputs()[0].name
                
                result = session.run([output_name], {input_name: dummy_input.numpy()})
                onnx_output = result[0]
                
                logging.info("✅ ONNX inference test passed")
            except ImportError:
                logging.warning("⚠️ ONNX Runtime not available for testing")
            except Exception as e:
                logging.error(f"❌ ONNX inference test failed: {e}")
        
        # Test TFLite if available
        if os.path.exists("emotion_model_float32.tflite"):
            try:
                import tensorflow as tf
                interpreter = tf.lite.Interpreter(model_path="emotion_model_float32.tflite")
                interpreter.allocate_tensors()
                
                input_details = interpreter.get_input_details()
                output_details = interpreter.get_output_details()
                
                # Convert input to the format expected by TFLite
                test_input = dummy_input.numpy().transpose(0, 2, 3, 1)  # NCHW to NHWC
                
                interpreter.set_tensor(input_details[0]['index'], test_input.astype(np.float32))
                interpreter.invoke()
                
                tflite_output = interpreter.get_tensor(output_details[0]['index'])
                logging.info("✅ TensorFlow Lite inference test passed")
                
            except ImportError:
                logging.warning("⚠️ TensorFlow not available for TFLite testing")
            except Exception as e:
                logging.error(f"❌ TensorFlow Lite inference test failed: {e}")
        
    except Exception as e:
        logging.error(f"❌ Model inference test failed: {e}")

def main():
    """Main conversion pipeline"""
    logging.info("🚀 Starting mobile model conversion pipeline...")
    
    # Check if trained model exists
    if not os.path.exists(MODEL_PATH):
        logging.error(f"❌ Trained model not found: {MODEL_PATH}")
        logging.info("Please run the training script first to generate the model.")
        return
    
    try:
        # Step 1: Load trained model
        model = load_trained_model()
        
        # Step 2: Save PyTorch variants
        traced_model = save_pytorch_model(model)
        
        # Step 3: Convert to ONNX
        onnx_path = convert_to_onnx(model)
        
        # Step 4: Convert to TensorFlow Lite (try ONNX route first)
        tflite_paths = None
        if onnx_path:
            try:
                import onnx2tf
                import tensorflow as tf
                tflite_paths = convert_to_tflite(onnx_path)
            except ImportError:
                logging.warning("⚠️ ONNX2TF not available, trying direct conversion...")
                tflite_paths = convert_to_tflite_direct(model)
        else:
            tflite_paths = convert_to_tflite_direct(model)
        
        if tflite_paths:
            logging.info(f"✅ Mobile models created: {tflite_paths}")
        
        # Step 5: Convert to Core ML
        coreml_path = convert_to_coreml(model)
        
        # Step 6: Create deployment metadata
        create_deployment_metadata()
        
        # Step 7: Test inference
        test_model_inference(model)
        
        # Summary
        logging.info("\n🎉 Model conversion completed successfully!")
        
        # List generated files
        generated_files = [
            "emotion_classifier_full.pt",
            "emotion_classifier_weights.pt", 
            "emotion_classifier_torchscript.pt",
            "emotion_model.onnx",
            "emotion_model_float32.tflite",
            "emotion_model_quantized.tflite",
            "emotion_model_mobile.pt",
            "EmotionClassifier.mlpackage",
            "EmotionClassifier_simple.mlpackage",
            "deployment_metadata.json",
            "class_mapping.json",
            "DEPLOYMENT_SUMMARY.md"
        ]
        
        logging.info("\n📁 Generated files:")
        total_size = 0
        for file in generated_files:
            if os.path.exists(file):
                if os.path.isdir(file):
                    # For .mlpackage directory
                    size = sum(os.path.getsize(os.path.join(file, f)) 
                             for f in os.listdir(file) if os.path.isfile(os.path.join(file, f)))
                else:
                    size = os.path.getsize(file)
                size_mb = size / (1024 * 1024)
                total_size += size_mb
                logging.info(f"   ✅ {file} ({size_mb:.2f} MB)")
            else:
                logging.info(f"   ❌ {file} (not created)")
        
        logging.info(f"\n📊 Total size: {total_size:.2f} MB")
        logging.info("📱 All mobile deployment files are ready!")
        logging.info("📋 Check DEPLOYMENT_SUMMARY.md for integration details")
        
    except Exception as e:
        logging.error(f"❌ Conversion pipeline failed: {e}")
        logging.info("\n📦 Required packages for conversion:")
        logging.info("pip install onnx onnx2tf tensorflow coremltools onnxruntime")

if __name__ == "__main__":
    main()
# Out:
# INFO:root:🚀 Starting mobile model conversion pipeline...
# 2025-06-14 18:44:28,551 - INFO - 🚀 Starting mobile model conversion pipeline...
# 2025-06-14 18:44:28,551 - INFO - 🚀 Starting mobile model conversion pipeline...
# 2025-06-14 18:44:28,551 - INFO - 🚀 Starting mobile model conversion pipeline...
# 2025-06-14 18:44:28,551 - INFO - 🚀 Starting mobile model conversion pipeline...
# 2025-06-14 18:44:28,551 - INFO - 🚀 Starting mobile model conversion pipeline...
# INFO:root:📥 Loading trained PyTorch model...
# 2025-06-14 18:44:28,558 - INFO - 📥 Loading trained PyTorch model...
# 2025-06-14 18:44:28,558 - INFO - 📥 Loading trained PyTorch model...
# 2025-06-14 18:44:28,558 - INFO - 📥 Loading trained PyTorch model...
# 2025-06-14 18:44:28,558 - INFO - 📥 Loading trained PyTorch model...
# 2025-06-14 18:44:28,558 - INFO - 📥 Loading trained PyTorch model...
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 18:44:28,938 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 18:44:28,938 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 18:44:28,938 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 18:44:28,938 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# 2025-06-14 18:44:28,938 - INFO - Loading pretrained weights from Hugging Face hub (timm/convnext_tiny.in12k_ft_in1k)
# INFO:timm.models._hub:[timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 18:44:28,983 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 18:44:28,983 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 18:44:28,983 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 18:44:28,983 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# 2025-06-14 18:44:28,983 - INFO - [timm/convnext_tiny.in12k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:root:✅ Model loaded successfully
# 2025-06-14 18:44:29,160 - INFO - ✅ Model loaded successfully
# 2025-06-14 18:44:29,160 - INFO - ✅ Model loaded successfully
# 2025-06-14 18:44:29,160 - INFO - ✅ Model loaded successfully
# 2025-06-14 18:44:29,160 - INFO - ✅ Model loaded successfully
# 2025-06-14 18:44:29,160 - INFO - ✅ Model loaded successfully
# INFO:root:💾 Saving optimized PyTorch model...
# 2025-06-14 18:44:29,175 - INFO - 💾 Saving optimized PyTorch model...
# 2025-06-14 18:44:29,175 - INFO - 💾 Saving optimized PyTorch model...
# 2025-06-14 18:44:29,175 - INFO - 💾 Saving optimized PyTorch model...
# 2025-06-14 18:44:29,175 - INFO - 💾 Saving optimized PyTorch model...
# 2025-06-14 18:44:29,175 - INFO - 💾 Saving optimized PyTorch model...
# INFO:root:✅ PyTorch models saved
# 2025-06-14 18:44:31,376 - INFO - ✅ PyTorch models saved
# 2025-06-14 18:44:31,376 - INFO - ✅ PyTorch models saved
# 2025-06-14 18:44:31,376 - INFO - ✅ PyTorch models saved
# 2025-06-14 18:44:31,376 - INFO - ✅ PyTorch models saved
# 2025-06-14 18:44:31,376 - INFO - ✅ PyTorch models saved
# INFO:root:🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:44:31,383 - INFO - 🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:44:31,383 - INFO - 🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:44:31,383 - INFO - 🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:44:31,383 - INFO - 🔄 Converting PyTorch to ONNX...
# 2025-06-14 18:44:31,383 - INFO - 🔄 Converting PyTorch to ONNX...
# INFO:root:✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:33,211 - INFO - ✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:33,211 - INFO - ✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:33,211 - INFO - ✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:33,211 - INFO - ✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:33,211 - INFO - ✅ ONNX model saved: emotion_model.onnx (106.27 MB)
# WARNING:root:⚠️ ONNX2TF not available, trying direct conversion...
# 2025-06-14 18:44:33,223 - WARNING - ⚠️ ONNX2TF not available, trying direct conversion...
# 2025-06-14 18:44:33,223 - WARNING - ⚠️ ONNX2TF not available, trying direct conversion...
# 2025-06-14 18:44:33,223 - WARNING - ⚠️ ONNX2TF not available, trying direct conversion...
# 2025-06-14 18:44:33,223 - WARNING - ⚠️ ONNX2TF not available, trying direct conversion...
# 2025-06-14 18:44:33,223 - WARNING - ⚠️ ONNX2TF not available, trying direct conversion...
# INFO:root:🔄 Creating mobile-optimized PyTorch model...
# 2025-06-14 18:44:33,226 - INFO - 🔄 Creating mobile-optimized PyTorch model...
# 2025-06-14 18:44:33,226 - INFO - 🔄 Creating mobile-optimized PyTorch model...
# 2025-06-14 18:44:33,226 - INFO - 🔄 Creating mobile-optimized PyTorch model...
# 2025-06-14 18:44:33,226 - INFO - 🔄 Creating mobile-optimized PyTorch model...
# 2025-06-14 18:44:33,226 - INFO - 🔄 Creating mobile-optimized PyTorch model...
# INFO:root:✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:36,016 - INFO - ✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:36,016 - INFO - ✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:36,016 - INFO - ✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:36,016 - INFO - ✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:36,016 - INFO - ✅ Mobile PyTorch model saved: emotion_model_mobile.pt (106.21 MB)
# INFO:root:ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# 2025-06-14 18:44:36,022 - INFO - ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# 2025-06-14 18:44:36,022 - INFO - ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# 2025-06-14 18:44:36,022 - INFO - ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# 2025-06-14 18:44:36,022 - INFO - ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# 2025-06-14 18:44:36,022 - INFO - ℹ️ For TensorFlow Lite conversion, install: pip install onnx2tf tensorflow
# INFO:root:ℹ️ Then re-run to get .tflite models for Android
# 2025-06-14 18:44:36,026 - INFO - ℹ️ Then re-run to get .tflite models for Android
# 2025-06-14 18:44:36,026 - INFO - ℹ️ Then re-run to get .tflite models for Android
# 2025-06-14 18:44:36,026 - INFO - ℹ️ Then re-run to get .tflite models for Android
# 2025-06-14 18:44:36,026 - INFO - ℹ️ Then re-run to get .tflite models for Android
# 2025-06-14 18:44:36,026 - INFO - ℹ️ Then re-run to get .tflite models for Android
# INFO:root:✅ Mobile models created: ['emotion_model_mobile.pt']
# 2025-06-14 18:44:36,035 - INFO - ✅ Mobile models created: ['emotion_model_mobile.pt']
# 2025-06-14 18:44:36,035 - INFO - ✅ Mobile models created: ['emotion_model_mobile.pt']
# 2025-06-14 18:44:36,035 - INFO - ✅ Mobile models created: ['emotion_model_mobile.pt']
# 2025-06-14 18:44:36,035 - INFO - ✅ Mobile models created: ['emotion_model_mobile.pt']
# 2025-06-14 18:44:36,035 - INFO - ✅ Mobile models created: ['emotion_model_mobile.pt']
# INFO:root:🔄 Converting PyTorch to Core ML (.mlpackage)...
# 2025-06-14 18:44:36,038 - INFO - 🔄 Converting PyTorch to Core ML (.mlpackage)...
# 2025-06-14 18:44:36,038 - INFO - 🔄 Converting PyTorch to Core ML (.mlpackage)...
# 2025-06-14 18:44:36,038 - INFO - 🔄 Converting PyTorch to Core ML (.mlpackage)...
# 2025-06-14 18:44:36,038 - INFO - 🔄 Converting PyTorch to Core ML (.mlpackage)...
# 2025-06-14 18:44:36,038 - INFO - 🔄 Converting PyTorch to Core ML (.mlpackage)...
# INFO:coremltools:Converting graph.
# 2025-06-14 18:44:37,807 - INFO - Converting graph.
# 2025-06-14 18:44:37,807 - INFO - Converting graph.
# 2025-06-14 18:44:37,807 - INFO - Converting graph.
# 2025-06-14 18:44:37,807 - INFO - Converting graph.
# 2025-06-14 18:44:37,807 - INFO - Converting graph.
# Converting PyTorch Frontend ==> MIL Ops:   0%|          | 0/430 [00:00<?, ? ops/s]INFO:coremltools:Converting op 4 : constant
# 2025-06-14 18:44:37,862 - INFO - Converting op 4 : constant
# 2025-06-14 18:44:37,862 - INFO - Converting op 4 : constant
# 2025-06-14 18:44:37,862 - INFO - Converting op 4 : constant
# 2025-06-14 18:44:37,862 - INFO - Converting op 4 : constant
# 2025-06-14 18:44:37,862 - INFO - Converting op 4 : constant
# INFO:coremltools:Converting op 5 : constant
# 2025-06-14 18:44:37,866 - INFO - Converting op 5 : constant
# 2025-06-14 18:44:37,866 - INFO - Converting op 5 : constant
# 2025-06-14 18:44:37,866 - INFO - Converting op 5 : constant
# 2025-06-14 18:44:37,866 - INFO - Converting op 5 : constant
# 2025-06-14 18:44:37,866 - INFO - Converting op 5 : constant
# INFO:coremltools:Converting op 6 : constant
# 2025-06-14 18:44:37,870 - INFO - Converting op 6 : constant
# 2025-06-14 18:44:37,870 - INFO - Converting op 6 : constant
# 2025-06-14 18:44:37,870 - INFO - Converting op 6 : constant
# 2025-06-14 18:44:37,870 - INFO - Converting op 6 : constant
# 2025-06-14 18:44:37,870 - INFO - Converting op 6 : constant
# INFO:coremltools:Converting op 7 : constant
# 2025-06-14 18:44:37,876 - INFO - Converting op 7 : constant
# 2025-06-14 18:44:37,876 - INFO - Converting op 7 : constant
# 2025-06-14 18:44:37,876 - INFO - Converting op 7 : constant
# 2025-06-14 18:44:37,876 - INFO - Converting op 7 : constant
# 2025-06-14 18:44:37,876 - INFO - Converting op 7 : constant
# INFO:coremltools:Converting op 8 : constant
# 2025-06-14 18:44:37,880 - INFO - Converting op 8 : constant
# 2025-06-14 18:44:37,880 - INFO - Converting op 8 : constant
# 2025-06-14 18:44:37,880 - INFO - Converting op 8 : constant
# 2025-06-14 18:44:37,880 - INFO - Converting op 8 : constant
# 2025-06-14 18:44:37,880 - INFO - Converting op 8 : constant
# INFO:coremltools:Converting op 9 : constant
# 2025-06-14 18:44:37,884 - INFO - Converting op 9 : constant
# 2025-06-14 18:44:37,884 - INFO - Converting op 9 : constant
# 2025-06-14 18:44:37,884 - INFO - Converting op 9 : constant
# 2025-06-14 18:44:37,884 - INFO - Converting op 9 : constant
# 2025-06-14 18:44:37,884 - INFO - Converting op 9 : constant
# INFO:coremltools:Converting op 10 : constant
# 2025-06-14 18:44:37,889 - INFO - Converting op 10 : constant
# 2025-06-14 18:44:37,889 - INFO - Converting op 10 : constant
# 2025-06-14 18:44:37,889 - INFO - Converting op 10 : constant
# 2025-06-14 18:44:37,889 - INFO - Converting op 10 : constant
# 2025-06-14 18:44:37,889 - INFO - Converting op 10 : constant
# INFO:coremltools:Converting op 11 : constant
# 2025-06-14 18:44:37,894 - INFO - Converting op 11 : constant
# 2025-06-14 18:44:37,894 - INFO - Converting op 11 : constant
# 2025-06-14 18:44:37,894 - INFO - Converting op 11 : constant
# 2025-06-14 18:44:37,894 - INFO - Converting op 11 : constant
# 2025-06-14 18:44:37,894 - INFO - Converting op 11 : constant
# INFO:coremltools:Converting op 12 : constant
# 2025-06-14 18:44:37,898 - INFO - Converting op 12 : constant
# 2025-06-14 18:44:37,898 - INFO - Converting op 12 : constant
# 2025-06-14 18:44:37,898 - INFO - Converting op 12 : constant
# 2025-06-14 18:44:37,898 - INFO - Converting op 12 : constant
# 2025-06-14 18:44:37,898 - INFO - Converting op 12 : constant
# INFO:coremltools:Converting op 13 : constant
# 2025-06-14 18:44:37,901 - INFO - Converting op 13 : constant
# 2025-06-14 18:44:37,901 - INFO - Converting op 13 : constant
# 2025-06-14 18:44:37,901 - INFO - Converting op 13 : constant
# 2025-06-14 18:44:37,901 - INFO - Converting op 13 : constant
# 2025-06-14 18:44:37,901 - INFO - Converting op 13 : constant
# INFO:coremltools:Converting op 14 : constant
# 2025-06-14 18:44:37,906 - INFO - Converting op 14 : constant
# 2025-06-14 18:44:37,906 - INFO - Converting op 14 : constant
# 2025-06-14 18:44:37,906 - INFO - Converting op 14 : constant
# 2025-06-14 18:44:37,906 - INFO - Converting op 14 : constant
# 2025-06-14 18:44:37,906 - INFO - Converting op 14 : constant
# INFO:coremltools:Converting op 15 : constant
# 2025-06-14 18:44:37,910 - INFO - Converting op 15 : constant
# 2025-06-14 18:44:37,910 - INFO - Converting op 15 : constant
# 2025-06-14 18:44:37,910 - INFO - Converting op 15 : constant
# 2025-06-14 18:44:37,910 - INFO - Converting op 15 : constant
# 2025-06-14 18:44:37,910 - INFO - Converting op 15 : constant
# INFO:coremltools:Converting op 16 : constant
# 2025-06-14 18:44:37,913 - INFO - Converting op 16 : constant
# 2025-06-14 18:44:37,913 - INFO - Converting op 16 : constant
# 2025-06-14 18:44:37,913 - INFO - Converting op 16 : constant
# 2025-06-14 18:44:37,913 - INFO - Converting op 16 : constant
# 2025-06-14 18:44:37,913 - INFO - Converting op 16 : constant
# INFO:coremltools:Converting op 17 : constant
# 2025-06-14 18:44:37,919 - INFO - Converting op 17 : constant
# 2025-06-14 18:44:37,919 - INFO - Converting op 17 : constant
# 2025-06-14 18:44:37,919 - INFO - Converting op 17 : constant
# 2025-06-14 18:44:37,919 - INFO - Converting op 17 : constant
# 2025-06-14 18:44:37,919 - INFO - Converting op 17 : constant
# INFO:coremltools:Converting op 18 : constant
# 2025-06-14 18:44:37,923 - INFO - Converting op 18 : constant
# 2025-06-14 18:44:37,923 - INFO - Converting op 18 : constant
# 2025-06-14 18:44:37,923 - INFO - Converting op 18 : constant
# 2025-06-14 18:44:37,923 - INFO - Converting op 18 : constant
# 2025-06-14 18:44:37,923 - INFO - Converting op 18 : constant
# INFO:coremltools:Converting op 26 : listconstruct
# 2025-06-14 18:44:37,928 - INFO - Converting op 26 : listconstruct
# 2025-06-14 18:44:37,928 - INFO - Converting op 26 : listconstruct
# 2025-06-14 18:44:37,928 - INFO - Converting op 26 : listconstruct
# 2025-06-14 18:44:37,928 - INFO - Converting op 26 : listconstruct
# 2025-06-14 18:44:37,928 - INFO - Converting op 26 : listconstruct
# INFO:coremltools:Converting op 27 : listconstruct
# 2025-06-14 18:44:37,933 - INFO - Converting op 27 : listconstruct
# 2025-06-14 18:44:37,933 - INFO - Converting op 27 : listconstruct
# 2025-06-14 18:44:37,933 - INFO - Converting op 27 : listconstruct
# 2025-06-14 18:44:37,933 - INFO - Converting op 27 : listconstruct
# 2025-06-14 18:44:37,933 - INFO - Converting op 27 : listconstruct
# INFO:coremltools:Converting op 28 : listconstruct
# 2025-06-14 18:44:37,938 - INFO - Converting op 28 : listconstruct
# 2025-06-14 18:44:37,938 - INFO - Converting op 28 : listconstruct
# 2025-06-14 18:44:37,938 - INFO - Converting op 28 : listconstruct
# 2025-06-14 18:44:37,938 - INFO - Converting op 28 : listconstruct
# 2025-06-14 18:44:37,938 - INFO - Converting op 28 : listconstruct
# INFO:coremltools:Converting op 29 : listconstruct
# 2025-06-14 18:44:37,943 - INFO - Converting op 29 : listconstruct
# 2025-06-14 18:44:37,943 - INFO - Converting op 29 : listconstruct
# 2025-06-14 18:44:37,943 - INFO - Converting op 29 : listconstruct
# 2025-06-14 18:44:37,943 - INFO - Converting op 29 : listconstruct
# 2025-06-14 18:44:37,943 - INFO - Converting op 29 : listconstruct
# INFO:coremltools:Converting op x.3 : _convolution
# 2025-06-14 18:44:37,947 - INFO - Converting op x.3 : _convolution
# 2025-06-14 18:44:37,947 - INFO - Converting op x.3 : _convolution
# 2025-06-14 18:44:37,947 - INFO - Converting op x.3 : _convolution
# 2025-06-14 18:44:37,947 - INFO - Converting op x.3 : _convolution
# 2025-06-14 18:44:37,947 - INFO - Converting op x.3 : _convolution
# INFO:coremltools:Converting op 33 : listconstruct
# 2025-06-14 18:44:37,955 - INFO - Converting op 33 : listconstruct
# 2025-06-14 18:44:37,955 - INFO - Converting op 33 : listconstruct
# 2025-06-14 18:44:37,955 - INFO - Converting op 33 : listconstruct
# 2025-06-14 18:44:37,955 - INFO - Converting op 33 : listconstruct
# 2025-06-14 18:44:37,955 - INFO - Converting op 33 : listconstruct
# Converting PyTorch Frontend ==> MIL Ops:   5%|▍         | 21/430 [00:00<00:01, 205.07 ops/s]INFO:coremltools:Converting op input.1 : permute
# 2025-06-14 18:44:37,965 - INFO - Converting op input.1 : permute
# 2025-06-14 18:44:37,965 - INFO - Converting op input.1 : permute
# 2025-06-14 18:44:37,965 - INFO - Converting op input.1 : permute
# 2025-06-14 18:44:37,965 - INFO - Converting op input.1 : permute
# 2025-06-14 18:44:37,965 - INFO - Converting op input.1 : permute
# INFO:coremltools:Converting op 35 : listconstruct
# 2025-06-14 18:44:37,970 - INFO - Converting op 35 : listconstruct
# 2025-06-14 18:44:37,970 - INFO - Converting op 35 : listconstruct
# 2025-06-14 18:44:37,970 - INFO - Converting op 35 : listconstruct
# 2025-06-14 18:44:37,970 - INFO - Converting op 35 : listconstruct
# 2025-06-14 18:44:37,970 - INFO - Converting op 35 : listconstruct
# INFO:coremltools:Converting op x.5 : layer_norm
# 2025-06-14 18:44:37,975 - INFO - Converting op x.5 : layer_norm
# 2025-06-14 18:44:37,975 - INFO - Converting op x.5 : layer_norm
# 2025-06-14 18:44:37,975 - INFO - Converting op x.5 : layer_norm
# 2025-06-14 18:44:37,975 - INFO - Converting op x.5 : layer_norm
# 2025-06-14 18:44:37,975 - INFO - Converting op x.5 : layer_norm
# INFO:coremltools:Converting op 37 : listconstruct
# 2025-06-14 18:44:37,981 - INFO - Converting op 37 : listconstruct
# 2025-06-14 18:44:37,981 - INFO - Converting op 37 : listconstruct
# 2025-06-14 18:44:37,981 - INFO - Converting op 37 : listconstruct
# 2025-06-14 18:44:37,981 - INFO - Converting op 37 : listconstruct
# 2025-06-14 18:44:37,981 - INFO - Converting op 37 : listconstruct
# INFO:coremltools:Converting op input.3 : permute
# 2025-06-14 18:44:37,985 - INFO - Converting op input.3 : permute
# 2025-06-14 18:44:37,985 - INFO - Converting op input.3 : permute
# 2025-06-14 18:44:37,985 - INFO - Converting op input.3 : permute
# 2025-06-14 18:44:37,985 - INFO - Converting op input.3 : permute
# 2025-06-14 18:44:37,985 - INFO - Converting op input.3 : permute
# INFO:coremltools:Converting op 53 : listconstruct
# 2025-06-14 18:44:37,992 - INFO - Converting op 53 : listconstruct
# 2025-06-14 18:44:37,992 - INFO - Converting op 53 : listconstruct
# 2025-06-14 18:44:37,992 - INFO - Converting op 53 : listconstruct
# 2025-06-14 18:44:37,992 - INFO - Converting op 53 : listconstruct
# 2025-06-14 18:44:37,992 - INFO - Converting op 53 : listconstruct
# INFO:coremltools:Converting op 54 : listconstruct
# 2025-06-14 18:44:37,996 - INFO - Converting op 54 : listconstruct
# 2025-06-14 18:44:37,996 - INFO - Converting op 54 : listconstruct
# 2025-06-14 18:44:37,996 - INFO - Converting op 54 : listconstruct
# 2025-06-14 18:44:37,996 - INFO - Converting op 54 : listconstruct
# 2025-06-14 18:44:37,996 - INFO - Converting op 54 : listconstruct
# INFO:coremltools:Converting op 55 : listconstruct
# 2025-06-14 18:44:38,001 - INFO - Converting op 55 : listconstruct
# 2025-06-14 18:44:38,001 - INFO - Converting op 55 : listconstruct
# 2025-06-14 18:44:38,001 - INFO - Converting op 55 : listconstruct
# 2025-06-14 18:44:38,001 - INFO - Converting op 55 : listconstruct
# 2025-06-14 18:44:38,001 - INFO - Converting op 55 : listconstruct
# INFO:coremltools:Converting op 56 : listconstruct
# 2025-06-14 18:44:38,005 - INFO - Converting op 56 : listconstruct
# 2025-06-14 18:44:38,005 - INFO - Converting op 56 : listconstruct
# 2025-06-14 18:44:38,005 - INFO - Converting op 56 : listconstruct
# 2025-06-14 18:44:38,005 - INFO - Converting op 56 : listconstruct
# 2025-06-14 18:44:38,005 - INFO - Converting op 56 : listconstruct
# INFO:coremltools:Converting op x.7 : _convolution
# 2025-06-14 18:44:38,009 - INFO - Converting op x.7 : _convolution
# 2025-06-14 18:44:38,009 - INFO - Converting op x.7 : _convolution
# 2025-06-14 18:44:38,009 - INFO - Converting op x.7 : _convolution
# 2025-06-14 18:44:38,009 - INFO - Converting op x.7 : _convolution
# 2025-06-14 18:44:38,009 - INFO - Converting op x.7 : _convolution
# INFO:coremltools:Converting op 58 : listconstruct
# 2025-06-14 18:44:38,022 - INFO - Converting op 58 : listconstruct
# 2025-06-14 18:44:38,022 - INFO - Converting op 58 : listconstruct
# 2025-06-14 18:44:38,022 - INFO - Converting op 58 : listconstruct
# 2025-06-14 18:44:38,022 - INFO - Converting op 58 : listconstruct
# 2025-06-14 18:44:38,022 - INFO - Converting op 58 : listconstruct
# INFO:coremltools:Converting op input.5 : permute
# 2025-06-14 18:44:38,027 - INFO - Converting op input.5 : permute
# 2025-06-14 18:44:38,027 - INFO - Converting op input.5 : permute
# 2025-06-14 18:44:38,027 - INFO - Converting op input.5 : permute
# 2025-06-14 18:44:38,027 - INFO - Converting op input.5 : permute
# 2025-06-14 18:44:38,027 - INFO - Converting op input.5 : permute
# INFO:coremltools:Converting op 62 : listconstruct
# 2025-06-14 18:44:38,033 - INFO - Converting op 62 : listconstruct
# 2025-06-14 18:44:38,033 - INFO - Converting op 62 : listconstruct
# 2025-06-14 18:44:38,033 - INFO - Converting op 62 : listconstruct
# 2025-06-14 18:44:38,033 - INFO - Converting op 62 : listconstruct
# 2025-06-14 18:44:38,033 - INFO - Converting op 62 : listconstruct
# INFO:coremltools:Converting op input.7 : layer_norm
# 2025-06-14 18:44:38,037 - INFO - Converting op input.7 : layer_norm
# 2025-06-14 18:44:38,037 - INFO - Converting op input.7 : layer_norm
# 2025-06-14 18:44:38,037 - INFO - Converting op input.7 : layer_norm
# 2025-06-14 18:44:38,037 - INFO - Converting op input.7 : layer_norm
# 2025-06-14 18:44:38,037 - INFO - Converting op input.7 : layer_norm
# INFO:coremltools:Converting op input.9 : linear
# 2025-06-14 18:44:38,043 - INFO - Converting op input.9 : linear
# 2025-06-14 18:44:38,043 - INFO - Converting op input.9 : linear
# 2025-06-14 18:44:38,043 - INFO - Converting op input.9 : linear
# 2025-06-14 18:44:38,043 - INFO - Converting op input.9 : linear
# 2025-06-14 18:44:38,043 - INFO - Converting op input.9 : linear
# INFO:coremltools:Converting op input.11 : gelu
# 2025-06-14 18:44:38,047 - INFO - Converting op input.11 : gelu
# 2025-06-14 18:44:38,047 - INFO - Converting op input.11 : gelu
# 2025-06-14 18:44:38,047 - INFO - Converting op input.11 : gelu
# 2025-06-14 18:44:38,047 - INFO - Converting op input.11 : gelu
# 2025-06-14 18:44:38,047 - INFO - Converting op input.11 : gelu
# INFO:coremltools:Converting op input.13 : dropout
# 2025-06-14 18:44:38,052 - INFO - Converting op input.13 : dropout
# 2025-06-14 18:44:38,052 - INFO - Converting op input.13 : dropout
# 2025-06-14 18:44:38,052 - INFO - Converting op input.13 : dropout
# 2025-06-14 18:44:38,052 - INFO - Converting op input.13 : dropout
# 2025-06-14 18:44:38,052 - INFO - Converting op input.13 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,056 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,056 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,056 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,056 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,056 - INFO - Setting pytorch op: dropout to no-op.
# INFO:coremltools:Converting op input.15 : linear
# 2025-06-14 18:44:38,060 - INFO - Converting op input.15 : linear
# 2025-06-14 18:44:38,060 - INFO - Converting op input.15 : linear
# 2025-06-14 18:44:38,060 - INFO - Converting op input.15 : linear
# 2025-06-14 18:44:38,060 - INFO - Converting op input.15 : linear
# 2025-06-14 18:44:38,060 - INFO - Converting op input.15 : linear
# INFO:coremltools:Converting op x.9 : dropout
# 2025-06-14 18:44:38,064 - INFO - Converting op x.9 : dropout
# 2025-06-14 18:44:38,064 - INFO - Converting op x.9 : dropout
# 2025-06-14 18:44:38,064 - INFO - Converting op x.9 : dropout
# 2025-06-14 18:44:38,064 - INFO - Converting op x.9 : dropout
# 2025-06-14 18:44:38,064 - INFO - Converting op x.9 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,070 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,070 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,070 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,070 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,070 - INFO - Setting pytorch op: dropout to no-op.
# INFO:coremltools:Converting op 75 : listconstruct
# 2025-06-14 18:44:38,075 - INFO - Converting op 75 : listconstruct
# 2025-06-14 18:44:38,075 - INFO - Converting op 75 : listconstruct
# 2025-06-14 18:44:38,075 - INFO - Converting op 75 : listconstruct
# 2025-06-14 18:44:38,075 - INFO - Converting op 75 : listconstruct
# 2025-06-14 18:44:38,075 - INFO - Converting op 75 : listconstruct
# INFO:coremltools:Converting op x.11 : permute
# 2025-06-14 18:44:38,079 - INFO - Converting op x.11 : permute
# 2025-06-14 18:44:38,079 - INFO - Converting op x.11 : permute
# 2025-06-14 18:44:38,079 - INFO - Converting op x.11 : permute
# 2025-06-14 18:44:38,079 - INFO - Converting op x.11 : permute
# 2025-06-14 18:44:38,079 - INFO - Converting op x.11 : permute
# Converting PyTorch Frontend ==> MIL Ops:  10%|▉         | 42/430 [00:00<00:02, 187.45 ops/s]INFO:coremltools:Converting op 77 : listconstruct
# 2025-06-14 18:44:38,084 - INFO - Converting op 77 : listconstruct
# 2025-06-14 18:44:38,084 - INFO - Converting op 77 : listconstruct
# 2025-06-14 18:44:38,084 - INFO - Converting op 77 : listconstruct
# 2025-06-14 18:44:38,084 - INFO - Converting op 77 : listconstruct
# 2025-06-14 18:44:38,084 - INFO - Converting op 77 : listconstruct
# INFO:coremltools:Converting op 78 : reshape
# 2025-06-14 18:44:38,089 - INFO - Converting op 78 : reshape
# 2025-06-14 18:44:38,089 - INFO - Converting op 78 : reshape
# 2025-06-14 18:44:38,089 - INFO - Converting op 78 : reshape
# 2025-06-14 18:44:38,089 - INFO - Converting op 78 : reshape
# 2025-06-14 18:44:38,089 - INFO - Converting op 78 : reshape
# INFO:coremltools:Converting op x.13 : mul
# 2025-06-14 18:44:38,095 - INFO - Converting op x.13 : mul
# 2025-06-14 18:44:38,095 - INFO - Converting op x.13 : mul
# 2025-06-14 18:44:38,095 - INFO - Converting op x.13 : mul
# 2025-06-14 18:44:38,095 - INFO - Converting op x.13 : mul
# 2025-06-14 18:44:38,095 - INFO - Converting op x.13 : mul
# INFO:coremltools:Converting op input.17 : add
# 2025-06-14 18:44:38,100 - INFO - Converting op input.17 : add
# 2025-06-14 18:44:38,100 - INFO - Converting op input.17 : add
# 2025-06-14 18:44:38,100 - INFO - Converting op input.17 : add
# 2025-06-14 18:44:38,100 - INFO - Converting op input.17 : add
# 2025-06-14 18:44:38,100 - INFO - Converting op input.17 : add
# INFO:coremltools:Converting op 87 : listconstruct
# 2025-06-14 18:44:38,105 - INFO - Converting op 87 : listconstruct
# 2025-06-14 18:44:38,105 - INFO - Converting op 87 : listconstruct
# 2025-06-14 18:44:38,105 - INFO - Converting op 87 : listconstruct
# 2025-06-14 18:44:38,105 - INFO - Converting op 87 : listconstruct
# 2025-06-14 18:44:38,105 - INFO - Converting op 87 : listconstruct
# INFO:coremltools:Converting op 88 : listconstruct
# 2025-06-14 18:44:38,109 - INFO - Converting op 88 : listconstruct
# 2025-06-14 18:44:38,109 - INFO - Converting op 88 : listconstruct
# 2025-06-14 18:44:38,109 - INFO - Converting op 88 : listconstruct
# 2025-06-14 18:44:38,109 - INFO - Converting op 88 : listconstruct
# 2025-06-14 18:44:38,109 - INFO - Converting op 88 : listconstruct
# INFO:coremltools:Converting op 89 : listconstruct
# 2025-06-14 18:44:38,114 - INFO - Converting op 89 : listconstruct
# 2025-06-14 18:44:38,114 - INFO - Converting op 89 : listconstruct
# 2025-06-14 18:44:38,114 - INFO - Converting op 89 : listconstruct
# 2025-06-14 18:44:38,114 - INFO - Converting op 89 : listconstruct
# 2025-06-14 18:44:38,114 - INFO - Converting op 89 : listconstruct
# INFO:coremltools:Converting op 90 : listconstruct
# 2025-06-14 18:44:38,119 - INFO - Converting op 90 : listconstruct
# 2025-06-14 18:44:38,119 - INFO - Converting op 90 : listconstruct
# 2025-06-14 18:44:38,119 - INFO - Converting op 90 : listconstruct
# 2025-06-14 18:44:38,119 - INFO - Converting op 90 : listconstruct
# 2025-06-14 18:44:38,119 - INFO - Converting op 90 : listconstruct
# INFO:coremltools:Converting op x.15 : _convolution
# 2025-06-14 18:44:38,124 - INFO - Converting op x.15 : _convolution
# 2025-06-14 18:44:38,124 - INFO - Converting op x.15 : _convolution
# 2025-06-14 18:44:38,124 - INFO - Converting op x.15 : _convolution
# 2025-06-14 18:44:38,124 - INFO - Converting op x.15 : _convolution
# 2025-06-14 18:44:38,124 - INFO - Converting op x.15 : _convolution
# INFO:coremltools:Converting op 92 : listconstruct
# 2025-06-14 18:44:38,129 - INFO - Converting op 92 : listconstruct
# 2025-06-14 18:44:38,129 - INFO - Converting op 92 : listconstruct
# 2025-06-14 18:44:38,129 - INFO - Converting op 92 : listconstruct
# 2025-06-14 18:44:38,129 - INFO - Converting op 92 : listconstruct
# 2025-06-14 18:44:38,129 - INFO - Converting op 92 : listconstruct
# INFO:coremltools:Converting op input.19 : permute
# 2025-06-14 18:44:38,135 - INFO - Converting op input.19 : permute
# 2025-06-14 18:44:38,135 - INFO - Converting op input.19 : permute
# 2025-06-14 18:44:38,135 - INFO - Converting op input.19 : permute
# 2025-06-14 18:44:38,135 - INFO - Converting op input.19 : permute
# 2025-06-14 18:44:38,135 - INFO - Converting op input.19 : permute
# INFO:coremltools:Converting op 96 : listconstruct
# 2025-06-14 18:44:38,140 - INFO - Converting op 96 : listconstruct
# 2025-06-14 18:44:38,140 - INFO - Converting op 96 : listconstruct
# 2025-06-14 18:44:38,140 - INFO - Converting op 96 : listconstruct
# 2025-06-14 18:44:38,140 - INFO - Converting op 96 : listconstruct
# 2025-06-14 18:44:38,140 - INFO - Converting op 96 : listconstruct
# INFO:coremltools:Converting op input.21 : layer_norm
# 2025-06-14 18:44:38,145 - INFO - Converting op input.21 : layer_norm
# 2025-06-14 18:44:38,145 - INFO - Converting op input.21 : layer_norm
# 2025-06-14 18:44:38,145 - INFO - Converting op input.21 : layer_norm
# 2025-06-14 18:44:38,145 - INFO - Converting op input.21 : layer_norm
# 2025-06-14 18:44:38,145 - INFO - Converting op input.21 : layer_norm
# INFO:coremltools:Converting op input.23 : linear
# 2025-06-14 18:44:38,150 - INFO - Converting op input.23 : linear
# 2025-06-14 18:44:38,150 - INFO - Converting op input.23 : linear
# 2025-06-14 18:44:38,150 - INFO - Converting op input.23 : linear
# 2025-06-14 18:44:38,150 - INFO - Converting op input.23 : linear
# 2025-06-14 18:44:38,150 - INFO - Converting op input.23 : linear
# INFO:coremltools:Converting op input.25 : gelu
# 2025-06-14 18:44:38,154 - INFO - Converting op input.25 : gelu
# 2025-06-14 18:44:38,154 - INFO - Converting op input.25 : gelu
# 2025-06-14 18:44:38,154 - INFO - Converting op input.25 : gelu
# 2025-06-14 18:44:38,154 - INFO - Converting op input.25 : gelu
# 2025-06-14 18:44:38,154 - INFO - Converting op input.25 : gelu
# INFO:coremltools:Converting op input.27 : dropout
# 2025-06-14 18:44:38,160 - INFO - Converting op input.27 : dropout
# 2025-06-14 18:44:38,160 - INFO - Converting op input.27 : dropout
# 2025-06-14 18:44:38,160 - INFO - Converting op input.27 : dropout
# 2025-06-14 18:44:38,160 - INFO - Converting op input.27 : dropout
# 2025-06-14 18:44:38,160 - INFO - Converting op input.27 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,164 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,164 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,164 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,164 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,164 - INFO - Setting pytorch op: dropout to no-op.
# INFO:coremltools:Converting op input.29 : linear
# 2025-06-14 18:44:38,167 - INFO - Converting op input.29 : linear
# 2025-06-14 18:44:38,167 - INFO - Converting op input.29 : linear
# 2025-06-14 18:44:38,167 - INFO - Converting op input.29 : linear
# 2025-06-14 18:44:38,167 - INFO - Converting op input.29 : linear
# 2025-06-14 18:44:38,167 - INFO - Converting op input.29 : linear
# INFO:coremltools:Converting op x.17 : dropout
# 2025-06-14 18:44:38,173 - INFO - Converting op x.17 : dropout
# 2025-06-14 18:44:38,173 - INFO - Converting op x.17 : dropout
# 2025-06-14 18:44:38,173 - INFO - Converting op x.17 : dropout
# 2025-06-14 18:44:38,173 - INFO - Converting op x.17 : dropout
# 2025-06-14 18:44:38,173 - INFO - Converting op x.17 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,177 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,177 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,177 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,177 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,177 - INFO - Setting pytorch op: dropout to no-op.
# INFO:coremltools:Converting op 109 : listconstruct
# 2025-06-14 18:44:38,182 - INFO - Converting op 109 : listconstruct
# 2025-06-14 18:44:38,182 - INFO - Converting op 109 : listconstruct
# 2025-06-14 18:44:38,182 - INFO - Converting op 109 : listconstruct
# 2025-06-14 18:44:38,182 - INFO - Converting op 109 : listconstruct
# 2025-06-14 18:44:38,182 - INFO - Converting op 109 : listconstruct
# Converting PyTorch Frontend ==> MIL Ops:  14%|█▍        | 61/430 [00:00<00:01, 186.01 ops/s]INFO:coremltools:Converting op x.19 : permute
# 2025-06-14 18:44:38,187 - INFO - Converting op x.19 : permute
# 2025-06-14 18:44:38,187 - INFO - Converting op x.19 : permute
# 2025-06-14 18:44:38,187 - INFO - Converting op x.19 : permute
# 2025-06-14 18:44:38,187 - INFO - Converting op x.19 : permute
# 2025-06-14 18:44:38,187 - INFO - Converting op x.19 : permute
# INFO:coremltools:Converting op 111 : listconstruct
# 2025-06-14 18:44:38,191 - INFO - Converting op 111 : listconstruct
# 2025-06-14 18:44:38,191 - INFO - Converting op 111 : listconstruct
# 2025-06-14 18:44:38,191 - INFO - Converting op 111 : listconstruct
# 2025-06-14 18:44:38,191 - INFO - Converting op 111 : listconstruct
# 2025-06-14 18:44:38,191 - INFO - Converting op 111 : listconstruct
# INFO:coremltools:Converting op 112 : reshape
# 2025-06-14 18:44:38,196 - INFO - Converting op 112 : reshape
# 2025-06-14 18:44:38,196 - INFO - Converting op 112 : reshape
# 2025-06-14 18:44:38,196 - INFO - Converting op 112 : reshape
# 2025-06-14 18:44:38,196 - INFO - Converting op 112 : reshape
# 2025-06-14 18:44:38,196 - INFO - Converting op 112 : reshape
# INFO:coremltools:Converting op x.21 : mul
# 2025-06-14 18:44:38,202 - INFO - Converting op x.21 : mul
# 2025-06-14 18:44:38,202 - INFO - Converting op x.21 : mul
# 2025-06-14 18:44:38,202 - INFO - Converting op x.21 : mul
# 2025-06-14 18:44:38,202 - INFO - Converting op x.21 : mul
# 2025-06-14 18:44:38,202 - INFO - Converting op x.21 : mul
# INFO:coremltools:Converting op input.31 : add
# 2025-06-14 18:44:38,207 - INFO - Converting op input.31 : add
# 2025-06-14 18:44:38,207 - INFO - Converting op input.31 : add
# 2025-06-14 18:44:38,207 - INFO - Converting op input.31 : add
# 2025-06-14 18:44:38,207 - INFO - Converting op input.31 : add
# 2025-06-14 18:44:38,207 - INFO - Converting op input.31 : add
# INFO:coremltools:Converting op 121 : listconstruct
# 2025-06-14 18:44:38,211 - INFO - Converting op 121 : listconstruct
# 2025-06-14 18:44:38,211 - INFO - Converting op 121 : listconstruct
# 2025-06-14 18:44:38,211 - INFO - Converting op 121 : listconstruct
# 2025-06-14 18:44:38,211 - INFO - Converting op 121 : listconstruct
# 2025-06-14 18:44:38,211 - INFO - Converting op 121 : listconstruct
# INFO:coremltools:Converting op 122 : listconstruct
# 2025-06-14 18:44:38,217 - INFO - Converting op 122 : listconstruct
# 2025-06-14 18:44:38,217 - INFO - Converting op 122 : listconstruct
# 2025-06-14 18:44:38,217 - INFO - Converting op 122 : listconstruct
# 2025-06-14 18:44:38,217 - INFO - Converting op 122 : listconstruct
# 2025-06-14 18:44:38,217 - INFO - Converting op 122 : listconstruct
# INFO:coremltools:Converting op 123 : listconstruct
# 2025-06-14 18:44:38,221 - INFO - Converting op 123 : listconstruct
# 2025-06-14 18:44:38,221 - INFO - Converting op 123 : listconstruct
# 2025-06-14 18:44:38,221 - INFO - Converting op 123 : listconstruct
# 2025-06-14 18:44:38,221 - INFO - Converting op 123 : listconstruct
# 2025-06-14 18:44:38,221 - INFO - Converting op 123 : listconstruct
# INFO:coremltools:Converting op 124 : listconstruct
# 2025-06-14 18:44:38,225 - INFO - Converting op 124 : listconstruct
# 2025-06-14 18:44:38,225 - INFO - Converting op 124 : listconstruct
# 2025-06-14 18:44:38,225 - INFO - Converting op 124 : listconstruct
# 2025-06-14 18:44:38,225 - INFO - Converting op 124 : listconstruct
# 2025-06-14 18:44:38,225 - INFO - Converting op 124 : listconstruct
# INFO:coremltools:Converting op x.23 : _convolution
# 2025-06-14 18:44:38,229 - INFO - Converting op x.23 : _convolution
# 2025-06-14 18:44:38,229 - INFO - Converting op x.23 : _convolution
# 2025-06-14 18:44:38,229 - INFO - Converting op x.23 : _convolution
# 2025-06-14 18:44:38,229 - INFO - Converting op x.23 : _convolution
# 2025-06-14 18:44:38,229 - INFO - Converting op x.23 : _convolution
# INFO:coremltools:Converting op 126 : listconstruct
# 2025-06-14 18:44:38,235 - INFO - Converting op 126 : listconstruct
# 2025-06-14 18:44:38,235 - INFO - Converting op 126 : listconstruct
# 2025-06-14 18:44:38,235 - INFO - Converting op 126 : listconstruct
# 2025-06-14 18:44:38,235 - INFO - Converting op 126 : listconstruct
# 2025-06-14 18:44:38,235 - INFO - Converting op 126 : listconstruct
# INFO:coremltools:Converting op input.33 : permute
# 2025-06-14 18:44:38,244 - INFO - Converting op input.33 : permute
# 2025-06-14 18:44:38,244 - INFO - Converting op input.33 : permute
# 2025-06-14 18:44:38,244 - INFO - Converting op input.33 : permute
# 2025-06-14 18:44:38,244 - INFO - Converting op input.33 : permute
# 2025-06-14 18:44:38,244 - INFO - Converting op input.33 : permute
# INFO:coremltools:Converting op 130 : listconstruct
# 2025-06-14 18:44:38,247 - INFO - Converting op 130 : listconstruct
# 2025-06-14 18:44:38,247 - INFO - Converting op 130 : listconstruct
# 2025-06-14 18:44:38,247 - INFO - Converting op 130 : listconstruct
# 2025-06-14 18:44:38,247 - INFO - Converting op 130 : listconstruct
# 2025-06-14 18:44:38,247 - INFO - Converting op 130 : listconstruct
# INFO:coremltools:Converting op input.35 : layer_norm
# 2025-06-14 18:44:38,251 - INFO - Converting op input.35 : layer_norm
# 2025-06-14 18:44:38,251 - INFO - Converting op input.35 : layer_norm
# 2025-06-14 18:44:38,251 - INFO - Converting op input.35 : layer_norm
# 2025-06-14 18:44:38,251 - INFO - Converting op input.35 : layer_norm
# 2025-06-14 18:44:38,251 - INFO - Converting op input.35 : layer_norm
# INFO:coremltools:Converting op input.37 : linear
# 2025-06-14 18:44:38,256 - INFO - Converting op input.37 : linear
# 2025-06-14 18:44:38,256 - INFO - Converting op input.37 : linear
# 2025-06-14 18:44:38,256 - INFO - Converting op input.37 : linear
# 2025-06-14 18:44:38,256 - INFO - Converting op input.37 : linear
# 2025-06-14 18:44:38,256 - INFO - Converting op input.37 : linear
# INFO:coremltools:Converting op input.39 : gelu
# 2025-06-14 18:44:38,260 - INFO - Converting op input.39 : gelu
# 2025-06-14 18:44:38,260 - INFO - Converting op input.39 : gelu
# 2025-06-14 18:44:38,260 - INFO - Converting op input.39 : gelu
# 2025-06-14 18:44:38,260 - INFO - Converting op input.39 : gelu
# 2025-06-14 18:44:38,260 - INFO - Converting op input.39 : gelu
# INFO:coremltools:Converting op input.41 : dropout
# 2025-06-14 18:44:38,268 - INFO - Converting op input.41 : dropout
# 2025-06-14 18:44:38,268 - INFO - Converting op input.41 : dropout
# 2025-06-14 18:44:38,268 - INFO - Converting op input.41 : dropout
# 2025-06-14 18:44:38,268 - INFO - Converting op input.41 : dropout
# 2025-06-14 18:44:38,268 - INFO - Converting op input.41 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,273 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,273 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,273 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,273 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,273 - INFO - Setting pytorch op: dropout to no-op.
# INFO:coremltools:Converting op input.43 : linear
# 2025-06-14 18:44:38,278 - INFO - Converting op input.43 : linear
# 2025-06-14 18:44:38,278 - INFO - Converting op input.43 : linear
# 2025-06-14 18:44:38,278 - INFO - Converting op input.43 : linear
# 2025-06-14 18:44:38,278 - INFO - Converting op input.43 : linear
# 2025-06-14 18:44:38,278 - INFO - Converting op input.43 : linear
# INFO:coremltools:Converting op x.25 : dropout
# 2025-06-14 18:44:38,282 - INFO - Converting op x.25 : dropout
# 2025-06-14 18:44:38,282 - INFO - Converting op x.25 : dropout
# 2025-06-14 18:44:38,282 - INFO - Converting op x.25 : dropout
# 2025-06-14 18:44:38,282 - INFO - Converting op x.25 : dropout
# 2025-06-14 18:44:38,282 - INFO - Converting op x.25 : dropout
# INFO:coremltools:Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,285 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,285 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,285 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,285 - INFO - Setting pytorch op: dropout to no-op.
# 2025-06-14 18:44:38,285 - INFO - Setting pytorch op: dropout to no-op.
# Converting PyTorch Frontend ==> MIL Ops:  19%|█▊        | 80/430 [00:00<00:01, 186.32 ops/s]INFO:coremltools:Converting op 143 : listconstruct
# 2025-06-14 18:44:38,291 - INFO - Converting op 143 : listconstruct
# 2025-06-14 18:44:38,291 - INFO - Converting op 143 : listconstruct
# 2025-06-14 18:44:38,291 - INFO - Converting op 143 : listconstruct
# 2025-06-14 18:44:38,291 - INFO - Converting op 143 : listconstruct
# 2025-06-14 18:44:38,291 - INFO - Converting op 143 : listconstruct
# INFO:coremltools:Converting op x.27 : permute
# 2025-06-14 18:44:38,295 - INFO - Converting op x.27 : permute
# 2025-06-14 18:44:38,295 - INFO - Converting op x.27 : permute
# 2025-06-14 18:44:38,295 - INFO - Converting op x.27 : permute
# 2025-06-14 18:44:38,295 - INFO - Converting op x.27 : permute
# 2025-06-14 18:44:38,295 - INFO - Converting op x.27 : permute
# INFO:coremltools:Converting op 145 : listconstruct
# 2025-06-14 18:44:38,300 - INFO - Converting op 145 : listconstruct
# 2025-06-14 18:44:38,300 - INFO - Converting op 145 : listconstruct
# 2025-06-14 18:44:38,300 - INFO - Converting op 145 : listconstruct
# 2025-06-14 18:44:38,300 - INFO - Converting op 145 : listconstruct
# 2025-06-14 18:44:38,300 - INFO - Converting op 145 : listconstruct
# INFO:coremltools:Converting op 146 : reshape
# 2025-06-14 18:44:38,305 - INFO - Converting op 146 : reshape
# 2025-06-14 18:44:38,305 - INFO - Converting op 146 : reshape
# 2025-06-14 18:44:38,305 - INFO - Converting op 146 : reshape
# 2025-06-14 18:44:38,305 - INFO - Converting op 146 : reshape
# 2025-06-14 18:44:38,305 - INFO - Converting op 146 : reshape
# INFO:coremltools:Converting op x.29 : mul
# 2025-06-14 18:44:38,310 - INFO - Converting op x.29 : mul
# 2025-06-14 18:44:38,310 - INFO - Converting op x.29 : mul
# 2025-06-14 18:44:38,310 - INFO - Converting op x.29 : mul
# 2025-06-14 18:44:38,310 - INFO - Converting op x.29 : mul
# 2025-06-14 18:44:38,310 - INFO - Converting op x.29 : mul
# INFO:coremltools:Converting op x.31 : add
# 2025-06-14 18:44:38,315 - INFO - Converting op x.31 : add
# 2025-06-14 18:44:38,315 - INFO - Converting op x.31 : add
# 2025-06-14 18:44:38,315 - INFO - Converting op x.31 : add
# 2025-06-14 18:44:38,315 - INFO - Converting op x.31 : add
# 2025-06-14 18:44:38,315 - INFO - Converting op x.31 : add
# INFO:coremltools:Converting op 155 : listconstruct
# 2025-06-14 18:44:38,321 - INFO - Converting op 155 : listconstruct
# 2025-06-14 18:44:38,321 - INFO - Converting op 155 : listconstruct
# 2025-06-14 18:44:38,321 - INFO - Converting op 155 : listconstruct
# 2025-06-14 18:44:38,321 - INFO - Converting op 155 : listconstruct
# 2025-06-14 18:44:38,321 - INFO - Converting op 155 : listconstruct
# INFO:coremltools:Converting op input.45 : permute
# 2025-06-14 18:44:38,325 - INFO - Converting op input.45 : permute
# 2025-06-14 18:44:38,325 - INFO - Converting op input.45 : permute
# 2025-06-14 18:44:38,325 - INFO - Converting op input.45 : permute
# 2025-06-14 18:44:38,325 - INFO - Converting op input.45 : permute
# 2025-06-14 18:44:38,325 - INFO - Converting op input.45 : permute
# INFO:coremltools:Converting op 157 : listconstruct
# 2025-06-14 18:44:38,330 - INFO - Converting op 157 : listconstruct
# 2025-06-14 18:44:38,330 - INFO - Converting op 157 : listconstruct
# 2025-06-14 18:44:38,330 - INFO - Converting op 157 : listconstruct
# 2025-06-14 18:44:38,330 - INFO - Converting op 157 : listconstruct
# 2025-06-14 18:44:38,330 - INFO - Converting op 157 : listconstruct
# INFO:coremltools:Converting op x.33 : layer_norm
# 2025-06-14 18:44:38,335 - INFO - Converting op x.33 : layer_norm
# 2025-06-14 18:44:38,335 - INFO - Converting op x.33 : layer_norm
# 2025-06-14 18:44:38,335 - INFO - Converting op x.33 : layer_norm
# 2025-06-14 18:44:38,335 - INFO - Converting op x.33 : layer_norm
# 2025-06-14 18:44:38,335 - INFO - Converting op x.33 : layer_norm
# INFO:coremltools:Converting op 159 : listconstruct
# 2025-06-14 18:44:38,341 - INFO - Converting op 159 : listconstruct
# 2025-06-14 18:44:38,341 - INFO - Converting op 159 : listconstruct
# 2025-06-14 18:44:38,341 - INFO - Converting op 159 : listconstruct
# 2025-06-14 18:44:38,341 - INFO - Converting op 159 : listconstruct
# 2025-06-14 18:44:38,341 - INFO - Converting op 159 : listconstruct
# INFO:coremltools:Converting op input.47 : permute
# 2025-06-14 18:44:38,346 - INFO - Converting op input.47 : permute
# 2025-06-14 18:44:38,346 - INFO - Converting op input.47 : permute
# 2025-06-14 18:44:38,346 - INFO - Converting op input.47 : permute
# 2025-06-14 18:44:38,346 - INFO - Converting op input.47 : permute
# 2025-06-14 18:44:38,346 - INFO - Converting op input.47 : permute
# INFO:coremltools:Converting op 163 : listconstruct
# 2025-06-14 18:44:38,351 - INFO - Converting op 163 : listconstruct
# 2025-06-14 18:44:38,351 - INFO - Converting op 163 : listconstruct
# 2025-06-14 18:44:38,351 - INFO - Converting op 163 : listconstruct
# 2025-06-14 18:44:38,351 - INFO - Converting op 163 : listconstruct
# 2025-06-14 18:44:38,351 - INFO - Converting op 163 : listconstruct
# INFO:coremltools:Converting op 164 : listconstruct
# 2025-06-14 18:44:38,356 - INFO - Converting op 164 : listconstruct
# 2025-06-14 18:44:38,356 - INFO - Converting op 164 : listconstruct
# 2025-06-14 18:44:38,356 - INFO - Converting op 164 : listconstruct
# 2025-06-14 18:44:38,356 - INFO - Converting op 164 : listconstruct
# 2025-06-14 18:44:38,356 - INFO - Converting op 164 : listconstruct
# INFO:coremltools:Converting op 165 : listconstruct
# 2025-06-14 18:44:38,361 - INFO - Converting op 165 : listconstruct
# 2025-06-14 18:44:38,361 - INFO - Converting op 165 : listconstruct
# 2025-06-14 18:44:38,361 - INFO - Converting op 165 : listconstruct
# 2025-06-14 18:44:38,361 - INFO - Converting op 165 : listconstruct
# 2025-06-14 18:44:38,361 - INFO - Converting op 165 : listconstruct
# INFO:coremltools:Converting op 166 : listconstruct
# 2025-06-14 18:44:38,366 - INFO - Converting op 166 : listconstruct
# 2025-06-14 18:44:38,366 - INFO - Converting op 166 : listconstruct
# 2025-06-14 18:44:38,366 - INFO - Converting op 166 : listconstruct
# 2025-06-14 18:44:38,366 - INFO - Converting op 166 : listconstruct
# 2025-06-14 18:44:38,366 - INFO - Converting op 166 : listconstruct
# INFO:coremltools:Converting op input.49 : _convolution
# 2025-06-14 18:44:38,370 - INFO - Converting op input.49 : _convolution
# 2025-06-14 18:44:38,370 - INFO - Converting op input.49 : _convolution
# 2025-06-14 18:44:38,370 - INFO - Converting op input.49 : _convolution
# 2025-06-14 18:44:38,370 - INFO - Converting op input.49 : _convolution
# 2025-06-14 18:44:38,370 - INFO - Converting op input.49 : _convolution
# INFO:coremltools:Converting op 177 : listconstruct
# 2025-06-14 18:44:38,377 - INFO - Converting op 177 : listconstruct
# 2025-06-14 18:44:38,377 - INFO - Converting op 177 : listconstruct
# 2025-06-14 18:44:38,377 - INFO - Converting op 177 : listconstruct
# 2025-06-14 18:44:38,377 - INFO - Converting op 177 : listconstruct
# 2025-06-14 18:44:38,377 - INFO - Converting op 177 : listconstruct
# INFO:coremltools:Converting op 178 : listconstruct
# 2025-06-14 18:44:38,382 - INFO - Converting op 178 : listconstruct
# 2025-06-14 18:44:38,382 - INFO - Converting op 178 : listconstruct
# 2025-06-14 18:44:38,382 - INFO - Converting op 178 : listconstruct
# 2025-06-14 18:44:38,382 - INFO - Converting op 178 : listconstruct
# ...
# 2025-06-14 18:44:53,711 - INFO - added const input.257_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:53,711 - INFO - added const input.257_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:53,711 - INFO - added const input.257_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:53,711 - INFO - added const input.257_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# INFO:coremltools:added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,773 - INFO - added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,773 - INFO - added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,773 - INFO - added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,773 - INFO - added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,773 - INFO - added const 728 for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# Translating MIL ==> NeuralNetwork Ops:  98%|█████████▊| 552/563 [00:12<00:00, 25.67 ops/s]INFO:coremltools:added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,781 - INFO - added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,781 - INFO - added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,781 - INFO - added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,781 - INFO - added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,781 - INFO - added const x_div_constant for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# INFO:coremltools:added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,786 - INFO - added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,786 - INFO - added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,786 - INFO - added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,786 - INFO - added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,786 - INFO - added const x_epsilon for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# INFO:coremltools:added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,790 - INFO - added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,790 - INFO - added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,790 - INFO - added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,790 - INFO - added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,790 - INFO - added const x_gamma for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# INFO:coremltools:added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,799 - INFO - added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,799 - INFO - added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,799 - INFO - added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,799 - INFO - added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# 2025-06-14 18:44:55,799 - INFO - added const x_beta for builder <coremltools.models.neural_network.builder.NeuralNetworkBuilder object at 0x7f97d98100d0>
# Translating MIL ==> NeuralNetwork Ops: 100%|██████████| 563/563 [00:12<00:00, 44.34 ops/s]
# INFO:root:✅ Core ML model saved: EmotionClassifier.mlpackage
# 2025-06-14 18:44:57,510 - INFO - ✅ Core ML model saved: EmotionClassifier.mlpackage
# 2025-06-14 18:44:57,510 - INFO - ✅ Core ML model saved: EmotionClassifier.mlpackage
# 2025-06-14 18:44:57,510 - INFO - ✅ Core ML model saved: EmotionClassifier.mlpackage
# 2025-06-14 18:44:57,510 - INFO - ✅ Core ML model saved: EmotionClassifier.mlpackage
# 2025-06-14 18:44:57,510 - INFO - ✅ Core ML model saved: EmotionClassifier.mlpackage
# INFO:root:ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# 2025-06-14 18:44:57,516 - INFO - ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# 2025-06-14 18:44:57,516 - INFO - ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# 2025-06-14 18:44:57,516 - INFO - ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# 2025-06-14 18:44:57,516 - INFO - ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# 2025-06-14 18:44:57,516 - INFO - ℹ️ Note: Manual image preprocessing required (resize to 224x224, normalize with ImageNet stats)
# INFO:root:📝 Creating deployment metadata...
# 2025-06-14 18:44:57,537 - INFO - 📝 Creating deployment metadata...
# 2025-06-14 18:44:57,537 - INFO - 📝 Creating deployment metadata...
# 2025-06-14 18:44:57,537 - INFO - 📝 Creating deployment metadata...
# 2025-06-14 18:44:57,537 - INFO - 📝 Creating deployment metadata...
# 2025-06-14 18:44:57,537 - INFO - 📝 Creating deployment metadata...
# INFO:root:✅ Deployment metadata created
# 2025-06-14 18:44:57,545 - INFO - ✅ Deployment metadata created
# 2025-06-14 18:44:57,545 - INFO - ✅ Deployment metadata created
# 2025-06-14 18:44:57,545 - INFO - ✅ Deployment metadata created
# 2025-06-14 18:44:57,545 - INFO - ✅ Deployment metadata created
# 2025-06-14 18:44:57,545 - INFO - ✅ Deployment metadata created
# INFO:root:🧪 Testing model inference...
# 2025-06-14 18:44:57,550 - INFO - 🧪 Testing model inference...
# 2025-06-14 18:44:57,550 - INFO - 🧪 Testing model inference...
# 2025-06-14 18:44:57,550 - INFO - 🧪 Testing model inference...
# 2025-06-14 18:44:57,550 - INFO - 🧪 Testing model inference...
# 2025-06-14 18:44:57,550 - INFO - 🧪 Testing model inference...
# INFO:root:✅ PyTorch inference test passed - Predicted class: 2
# 2025-06-14 18:44:57,599 - INFO - ✅ PyTorch inference test passed - Predicted class: 2
# 2025-06-14 18:44:57,599 - INFO - ✅ PyTorch inference test passed - Predicted class: 2
# 2025-06-14 18:44:57,599 - INFO - ✅ PyTorch inference test passed - Predicted class: 2
# 2025-06-14 18:44:57,599 - INFO - ✅ PyTorch inference test passed - Predicted class: 2
# 2025-06-14 18:44:57,599 - INFO - ✅ PyTorch inference test passed - Predicted class: 2
# WARNING:root:⚠️ ONNX Runtime not available for testing
# 2025-06-14 18:44:57,606 - WARNING - ⚠️ ONNX Runtime not available for testing
# 2025-06-14 18:44:57,606 - WARNING - ⚠️ ONNX Runtime not available for testing
# 2025-06-14 18:44:57,606 - WARNING - ⚠️ ONNX Runtime not available for testing
# 2025-06-14 18:44:57,606 - WARNING - ⚠️ ONNX Runtime not available for testing
# 2025-06-14 18:44:57,606 - WARNING - ⚠️ ONNX Runtime not available for testing
# INFO:root:
# 🎉 Model conversion completed successfully!
# 2025-06-14 18:44:57,611 - INFO -
# 🎉 Model conversion completed successfully!
# 2025-06-14 18:44:57,611 - INFO -
# 🎉 Model conversion completed successfully!
# 2025-06-14 18:44:57,611 - INFO -
# 🎉 Model conversion completed successfully!
# 2025-06-14 18:44:57,611 - INFO -
# 🎉 Model conversion completed successfully!
# 2025-06-14 18:44:57,611 - INFO -
# 🎉 Model conversion completed successfully!
# INFO:root:
# 📁 Generated files:
# 2025-06-14 18:44:57,616 - INFO -
# 📁 Generated files:
# 2025-06-14 18:44:57,616 - INFO -
# 📁 Generated files:
# 2025-06-14 18:44:57,616 - INFO -
# 📁 Generated files:
# 2025-06-14 18:44:57,616 - INFO -
# 📁 Generated files:
# 2025-06-14 18:44:57,616 - INFO -
# 📁 Generated files:
# INFO:root:   ✅ emotion_classifier_full.pt (106.25 MB)
# 2025-06-14 18:44:57,623 - INFO -    ✅ emotion_classifier_full.pt (106.25 MB)
# 2025-06-14 18:44:57,623 - INFO -    ✅ emotion_classifier_full.pt (106.25 MB)
# 2025-06-14 18:44:57,623 - INFO -    ✅ emotion_classifier_full.pt (106.25 MB)
# 2025-06-14 18:44:57,623 - INFO -    ✅ emotion_classifier_full.pt (106.25 MB)
# 2025-06-14 18:44:57,623 - INFO -    ✅ emotion_classifier_full.pt (106.25 MB)
# INFO:root:   ✅ emotion_classifier_weights.pt (106.21 MB)
# 2025-06-14 18:44:57,627 - INFO -    ✅ emotion_classifier_weights.pt (106.21 MB)
# 2025-06-14 18:44:57,627 - INFO -    ✅ emotion_classifier_weights.pt (106.21 MB)
# 2025-06-14 18:44:57,627 - INFO -    ✅ emotion_classifier_weights.pt (106.21 MB)
# 2025-06-14 18:44:57,627 - INFO -    ✅ emotion_classifier_weights.pt (106.21 MB)
# 2025-06-14 18:44:57,627 - INFO -    ✅ emotion_classifier_weights.pt (106.21 MB)
# INFO:root:   ✅ emotion_classifier_torchscript.pt (106.60 MB)
# 2025-06-14 18:44:57,633 - INFO -    ✅ emotion_classifier_torchscript.pt (106.60 MB)
# 2025-06-14 18:44:57,633 - INFO -    ✅ emotion_classifier_torchscript.pt (106.60 MB)
# 2025-06-14 18:44:57,633 - INFO -    ✅ emotion_classifier_torchscript.pt (106.60 MB)
# 2025-06-14 18:44:57,633 - INFO -    ✅ emotion_classifier_torchscript.pt (106.60 MB)
# 2025-06-14 18:44:57,633 - INFO -    ✅ emotion_classifier_torchscript.pt (106.60 MB)
# INFO:root:   ✅ emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:57,636 - INFO -    ✅ emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:57,636 - INFO -    ✅ emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:57,636 - INFO -    ✅ emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:57,636 - INFO -    ✅ emotion_model.onnx (106.27 MB)
# 2025-06-14 18:44:57,636 - INFO -    ✅ emotion_model.onnx (106.27 MB)
# INFO:root:   ❌ emotion_model_float32.tflite (not created)
# 2025-06-14 18:44:57,641 - INFO -    ❌ emotion_model_float32.tflite (not created)
# 2025-06-14 18:44:57,641 - INFO -    ❌ emotion_model_float32.tflite (not created)
# 2025-06-14 18:44:57,641 - INFO -    ❌ emotion_model_float32.tflite (not created)
# 2025-06-14 18:44:57,641 - INFO -    ❌ emotion_model_float32.tflite (not created)
# 2025-06-14 18:44:57,641 - INFO -    ❌ emotion_model_float32.tflite (not created)
# INFO:root:   ❌ emotion_model_quantized.tflite (not created)
# 2025-06-14 18:44:57,646 - INFO -    ❌ emotion_model_quantized.tflite (not created)
# 2025-06-14 18:44:57,646 - INFO -    ❌ emotion_model_quantized.tflite (not created)
# 2025-06-14 18:44:57,646 - INFO -    ❌ emotion_model_quantized.tflite (not created)
# 2025-06-14 18:44:57,646 - INFO -    ❌ emotion_model_quantized.tflite (not created)
# 2025-06-14 18:44:57,646 - INFO -    ❌ emotion_model_quantized.tflite (not created)
# INFO:root:   ✅ emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:57,652 - INFO -    ✅ emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:57,652 - INFO -    ✅ emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:57,652 - INFO -    ✅ emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:57,652 - INFO -    ✅ emotion_model_mobile.pt (106.21 MB)
# 2025-06-14 18:44:57,652 - INFO -    ✅ emotion_model_mobile.pt (106.21 MB)
# INFO:root:   ✅ EmotionClassifier.mlpackage (0.00 MB)
# 2025-06-14 18:44:57,657 - INFO -    ✅ EmotionClassifier.mlpackage (0.00 MB)
# 2025-06-14 18:44:57,657 - INFO -    ✅ EmotionClassifier.mlpackage (0.00 MB)
# 2025-06-14 18:44:57,657 - INFO -    ✅ EmotionClassifier.mlpackage (0.00 MB)
# 2025-06-14 18:44:57,657 - INFO -    ✅ EmotionClassifier.mlpackage (0.00 MB)
# 2025-06-14 18:44:57,657 - INFO -    ✅ EmotionClassifier.mlpackage (0.00 MB)
# INFO:root:   ❌ EmotionClassifier_simple.mlpackage (not created)
# 2025-06-14 18:44:57,662 - INFO -    ❌ EmotionClassifier_simple.mlpackage (not created)
# 2025-06-14 18:44:57,662 - INFO -    ❌ EmotionClassifier_simple.mlpackage (not created)
# 2025-06-14 18:44:57,662 - INFO -    ❌ EmotionClassifier_simple.mlpackage (not created)
# 2025-06-14 18:44:57,662 - INFO -    ❌ EmotionClassifier_simple.mlpackage (not created)
# 2025-06-14 18:44:57,662 - INFO -    ❌ EmotionClassifier_simple.mlpackage (not created)
# INFO:root:   ✅ deployment_metadata.json (0.00 MB)
# 2025-06-14 18:44:57,667 - INFO -    ✅ deployment_metadata.json (0.00 MB)
# 2025-06-14 18:44:57,667 - INFO -    ✅ deployment_metadata.json (0.00 MB)
# 2025-06-14 18:44:57,667 - INFO -    ✅ deployment_metadata.json (0.00 MB)
# 2025-06-14 18:44:57,667 - INFO -    ✅ deployment_metadata.json (0.00 MB)
# 2025-06-14 18:44:57,667 - INFO -    ✅ deployment_metadata.json (0.00 MB)
# INFO:root:   ✅ class_mapping.json (0.00 MB)
# 2025-06-14 18:44:57,671 - INFO -    ✅ class_mapping.json (0.00 MB)
# 2025-06-14 18:44:57,671 - INFO -    ✅ class_mapping.json (0.00 MB)
# 2025-06-14 18:44:57,671 - INFO -    ✅ class_mapping.json (0.00 MB)
# 2025-06-14 18:44:57,671 - INFO -    ✅ class_mapping.json (0.00 MB)
# 2025-06-14 18:44:57,671 - INFO -    ✅ class_mapping.json (0.00 MB)
# INFO:root:   ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# 2025-06-14 18:44:57,676 - INFO -    ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# 2025-06-14 18:44:57,676 - INFO -    ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# 2025-06-14 18:44:57,676 - INFO -    ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# 2025-06-14 18:44:57,676 - INFO -    ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# 2025-06-14 18:44:57,676 - INFO -    ✅ DEPLOYMENT_SUMMARY.md (0.00 MB)
# INFO:root:
# 📊 Total size: 531.53 MB
# 2025-06-14 18:44:57,680 - INFO -
# 📊 Total size: 531.53 MB
# 2025-06-14 18:44:57,680 - INFO -
# 📊 Total size: 531.53 MB
# 2025-06-14 18:44:57,680 - INFO -
# 📊 Total size: 531.53 MB
# 2025-06-14 18:44:57,680 - INFO -
# 📊 Total size: 531.53 MB
# 2025-06-14 18:44:57,680 - INFO -
# 📊 Total size: 531.53 MB
# INFO:root:📱 All mobile deployment files are ready!
# 2025-06-14 18:44:57,684 - INFO - 📱 All mobile deployment files are ready!
# 2025-06-14 18:44:57,684 - INFO - 📱 All mobile deployment files are ready!
# 2025-06-14 18:44:57,684 - INFO - 📱 All mobile deployment files are ready!
# 2025-06-14 18:44:57,684 - INFO - 📱 All mobile deployment files are ready!
# 2025-06-14 18:44:57,684 - INFO - 📱 All mobile deployment files are ready!
# INFO:root:📋 Check DEPLOYMENT_SUMMARY.md for integration details
# 2025-06-14 18:44:57,687 - INFO - 📋 Check DEPLOYMENT_SUMMARY.md for integration details
# 2025-06-14 18:44:57,687 - INFO - 📋 Check DEPLOYMENT_SUMMARY.md for integration details
# 2025-06-14 18:44:57,687 - INFO - 📋 Check DEPLOYMENT_SUMMARY.md for integration details
# 2025-06-14 18:44:57,687 - INFO - 📋 Check DEPLOYMENT_SUMMARY.md for integration details
# 2025-06-14 18:44:57,687 - INFO - 📋 Check DEPLOYMENT_SUMMARY.md for integration details

# %%
# !pip install onnx onnx-tf tensorflow
import torch
import timm

# Configuration
MODEL_NAME = "convnext_tiny"
NUM_CLASSES = 4
ONNX_PATH = "emotion_model.onnx"

# Load model
model = timm.create_model(MODEL_NAME, pretrained=False, num_classes=NUM_CLASSES)
model.load_state_dict(torch.load("best_emotion_model.pt", map_location="cpu"))
model.eval()

# Dummy input
dummy_input = torch.randn(1, 3, 224, 224)

# Export to ONNX
torch.onnx.export(
    model, dummy_input, ONNX_PATH,
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={'input': {0: 'batch_size'}, 'output': {0: 'batch_size'}},
    opset_version=11
)
print("✅ Exported to ONNX:", ONNX_PATH)

# %%
# !pip install tensorflow==2.13.0 tensorflow-probability==0.20.0 onnx==1.14.0 onnx-tf==1.10.0

import onnx
from onnx_tf.backend import prepare
import tensorflow as tf

# Load ONNX and convert to TF SavedModel
onnx_model = onnx.load("emotion_model.onnx")
tf_rep = prepare(onnx_model)
tf_rep.export_graph("saved_model")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_saved_model("saved_model")
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

# Save
with open("emotion_model.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Converted to TFLite: emotion_model.tflite")

# %%
# !pip install onnx

# %%
# !pip uninstall coremltools -y
# !pip install coremltools

# %%
# !pip install --upgrade pip
# !pip install coremltools==8.3.0 onnx
# Out:
# Requirement already satisfied: pip in /venv/main/lib/python3.10/site-packages (22.0.2)
# Collecting pip
#   Downloading pip-25.1.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# Successfully installed pip-25.1.1
# Requirement already satisfied: coremltools==8.3.0 in /venv/main/lib/python3.10/site-packages (8.3.0)
# Requirement already satisfied: onnx in /venv/main/lib/python3.10/site-packages (1.14.0)
# Requirement already satisfied: numpy>=1.14.5 in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (1.24.3)
# Requirement already satisfied: protobuf>=3.1.0 in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (4.25.8)
# Requirement already satisfied: sympy in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (1.14.0)
# Requirement already satisfied: tqdm in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (4.67.1)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (25.0)
# Requirement already satisfied: attrs>=21.3.0 in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (25.3.0)
# Requirement already satisfied: cattrs in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (25.1.1)
# Requirement already satisfied: pyaml in /venv/main/lib/python3.10/site-packages (from coremltools==8.3.0) (25.5.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /venv/main/lib/python3.10/site-packages (from onnx) (4.14.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /venv/main/lib/python3.10/site-packages (from cattrs->coremltools==8.3.0) (1.2.2)
# Requirement already satisfied: PyYAML in /venv/main/lib/python3.10/site-packages (from pyaml->coremltools==8.3.0) (6.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy->coremltools==8.3.0) (1.3.0)

# %%
import coremltools as ct
import os

print(f"CoreMLTools version: {ct.__version__}")

# Check if emotion_model.onnx exists
onnx_model_path = "emotion_model.onnx"
if not os.path.exists(onnx_model_path):
    print(f"Error: ONNX model file '{onnx_model_path}' not found. Please ensure it's in the same directory.")
else:
    try:
        mlmodel = ct.converters.onnx.convert(
            onnx_model_path,
            minimum_ios_deployment_target="13"
        )
        mlmodel.save("emotion_model.mlpackage")
        print("Model converted and saved successfully!")
    except AttributeError as e:
        print(f"AttributeError during conversion: {e}")
        print("This still indicates a fundamental issue with coremltools installation.")
    except Exception as e:
        print(f"An unexpected error occurred during conversion: {e}")
# Out:
# CoreMLTools version: 8.3.0
# AttributeError during conversion: module 'coremltools.converters' has no attribute 'onnx'
# This still indicates a fundamental issue with coremltools installation.
